# %% [markdown]
# ### Single Agent

# %%
import numpy as np

# Parameters
valuation = 50
discount_rate = 0.999
learning_rate = 0.01
epsilon_start = 0.99
epsilon_min = 0.01
epsilon_decay = 0.9999999
num_rounds = 10
num_actions = 5
num_games = 10_000_000
verbose_interval = 10000

actions = np.arange(num_actions)  # Action space 0-10
q_table = np.random.uniform(valuation,valuation+1,(num_rounds + 1, 2, len(actions)))  # Q-table
p = np.arange(num_actions,0,-1)**3.0
p /= p.sum()
print(p)

def train_agent():
    global epsilon_start
    reward_history_q = []
    reward_history_random = []
    epsilon = epsilon_start

    for game in range(num_games):
        t = num_rounds
        s = 0
        current_bid_q = 0
        current_bid_random = 0

        while t > 0:
            state_q = (t, s)
            action_q = np.random.choice(actions) if np.random.rand() < epsilon else actions[np.argmax(q_table[state_q])]
            current_bid_q += action_q
            action_random = np.random.choice(actions, p=p)
            current_bid_random += action_random
            s = 1 if current_bid_q >= current_bid_random else 0
            t -= 1
        reward_q = (valuation - current_bid_q) if (current_bid_q > current_bid_random) and (current_bid_q <= valuation) else 0
        reward_random = (valuation - current_bid_random) if (current_bid_random > current_bid_q) and (current_bid_random <= valuation) else 0
        reward_history_q.append(reward_q)
        reward_history_random.append(reward_random)

        if (game + 1) % verbose_interval == 0:
            print(f"Game {game + 1}: Epsilon: {epsilon:.4f}, Avg Q-Learn: {np.mean(reward_history_q[-verbose_interval:])}, Avg Random: {np.mean(reward_history_random[-verbose_interval:])}")

        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        state_q = (num_rounds, s)  # Reset state for Q-learning update
        update_q(state_q, action_q, reward_q, (t, s), t == 1)

    return q_table, reward_history_q, reward_history_random

def update_q(state, action, reward, next_state, done):
    future = 0 if done else discount_rate * np.max(q_table[next_state])
    q_table[state][action] += learning_rate * (reward + future - q_table[state][action])

q_table, reward_history_q, reward_history_random = train_agent()
# Out:
# [0.55555556 0.28444444 0.12       0.03555556 0.00444444]
# Game 10000: Epsilon: 0.9890, Avg Q-Learn: 29.8244, Avg Random: 0.1487
# Game 20000: Epsilon: 0.9880, Avg Q-Learn: 29.7276, Avg Random: 0.142
# Game 30000: Epsilon: 0.9870, Avg Q-Learn: 29.7887, Avg Random: 0.1544
# Game 40000: Epsilon: 0.9860, Avg Q-Learn: 29.8084, Avg Random: 0.1138
# Game 50000: Epsilon: 0.9851, Avg Q-Learn: 29.78, Avg Random: 0.167
# Game 60000: Epsilon: 0.9841, Avg Q-Learn: 29.7888, Avg Random: 0.1482
# Game 70000: Epsilon: 0.9831, Avg Q-Learn: 29.808, Avg Random: 0.1706
# Game 80000: Epsilon: 0.9821, Avg Q-Learn: 29.7733, Avg Random: 0.1785
# Game 90000: Epsilon: 0.9811, Avg Q-Learn: 29.756, Avg Random: 0.1484
# Game 100000: Epsilon: 0.9801, Avg Q-Learn: 29.8353, Avg Random: 0.1279
# Game 110000: Epsilon: 0.9792, Avg Q-Learn: 29.7649, Avg Random: 0.1786
# Game 120000: Epsilon: 0.9782, Avg Q-Learn: 29.8407, Avg Random: 0.1507
# Game 130000: Epsilon: 0.9772, Avg Q-Learn: 29.8659, Avg Random: 0.146
# Game 140000: Epsilon: 0.9762, Avg Q-Learn: 29.7805, Avg Random: 0.1348
# Game 150000: Epsilon: 0.9753, Avg Q-Learn: 29.7786, Avg Random: 0.1763
# Game 160000: Epsilon: 0.9743, Avg Q-Learn: 29.7799, Avg Random: 0.1833
# Game 170000: Epsilon: 0.9733, Avg Q-Learn: 29.8224, Avg Random: 0.1558
# Game 180000: Epsilon: 0.9723, Avg Q-Learn: 29.8003, Avg Random: 0.1456
# Game 190000: Epsilon: 0.9714, Avg Q-Learn: 29.7329, Avg Random: 0.1535
# Game 200000: Epsilon: 0.9704, Avg Q-Learn: 29.8089, Avg Random: 0.136
# Game 210000: Epsilon: 0.9694, Avg Q-Learn: 29.8759, Avg Random: 0.11
# Game 220000: Epsilon: 0.9685, Avg Q-Learn: 29.7887, Avg Random: 0.123
# Game 230000: Epsilon: 0.9675, Avg Q-Learn: 29.8221, Avg Random: 0.1395
# Game 240000: Epsilon: 0.9665, Avg Q-Learn: 29.8142, Avg Random: 0.1271
# Game 250000: Epsilon: 0.9656, Avg Q-Learn: 29.7675, Avg Random: 0.1474
# Game 260000: Epsilon: 0.9646, Avg Q-Learn: 29.7555, Avg Random: 0.1814
# Game 270000: Epsilon: 0.9636, Avg Q-Learn: 29.7604, Avg Random: 0.1809
# Game 280000: Epsilon: 0.9627, Avg Q-Learn: 29.8301, Avg Random: 0.1611
# Game 290000: Epsilon: 0.9617, Avg Q-Learn: 29.8323, Avg Random: 0.1565
# Game 300000: Epsilon: 0.9607, Avg Q-Learn: 29.7987, Avg Random: 0.1813
# Game 310000: Epsilon: 0.9598, Avg Q-Learn: 29.9257, Avg Random: 0.1537
# Game 320000: Epsilon: 0.9588, Avg Q-Learn: 29.8652, Avg Random: 0.1827
# Game 330000: Epsilon: 0.9579, Avg Q-Learn: 29.785, Avg Random: 0.1523
# Game 340000: Epsilon: 0.9569, Avg Q-Learn: 29.8418, Avg Random: 0.1746
# Game 350000: Epsilon: 0.9559, Avg Q-Learn: 29.882, Avg Random: 0.1482
# Game 360000: Epsilon: 0.9550, Avg Q-Learn: 29.8222, Avg Random: 0.13
# Game 370000: Epsilon: 0.9540, Avg Q-Learn: 29.822, Avg Random: 0.1555
# Game 380000: Epsilon: 0.9531, Avg Q-Learn: 29.9597, Avg Random: 0.0912
# Game 390000: Epsilon: 0.9521, Avg Q-Learn: 29.902, Avg Random: 0.1208
# Game 400000: Epsilon: 0.9512, Avg Q-Learn: 29.8419, Avg Random: 0.15
# Game 410000: Epsilon: 0.9502, Avg Q-Learn: 29.8853, Avg Random: 0.1692
# Game 420000: Epsilon: 0.9493, Avg Q-Learn: 29.9429, Avg Random: 0.1409
# Game 430000: Epsilon: 0.9483, Avg Q-Learn: 29.8176, Avg Random: 0.1529
# Game 440000: Epsilon: 0.9474, Avg Q-Learn: 29.8737, Avg Random: 0.1801
# Game 450000: Epsilon: 0.9464, Avg Q-Learn: 29.92, Avg Random: 0.1515
# Game 460000: Epsilon: 0.9455, Avg Q-Learn: 29.8891, Avg Random: 0.137
# Game 470000: Epsilon: 0.9445, Avg Q-Learn: 29.7789, Avg Random: 0.1572
# Game 480000: Epsilon: 0.9436, Avg Q-Learn: 29.8826, Avg Random: 0.1805
# Game 490000: Epsilon: 0.9427, Avg Q-Learn: 29.8486, Avg Random: 0.1673
# Game 500000: Epsilon: 0.9417, Avg Q-Learn: 29.9628, Avg Random: 0.1421
# Game 510000: Epsilon: 0.9408, Avg Q-Learn: 29.9217, Avg Random: 0.147
# Game 520000: Epsilon: 0.9398, Avg Q-Learn: 29.9865, Avg Random: 0.127
# Game 530000: Epsilon: 0.9389, Avg Q-Learn: 29.9157, Avg Random: 0.1705
# Game 540000: Epsilon: 0.9380, Avg Q-Learn: 29.9333, Avg Random: 0.1691
# Game 550000: Epsilon: 0.9370, Avg Q-Learn: 29.8784, Avg Random: 0.133
# Game 560000: Epsilon: 0.9361, Avg Q-Learn: 29.9086, Avg Random: 0.1495
# Game 570000: Epsilon: 0.9351, Avg Q-Learn: 29.9056, Avg Random: 0.171
# Game 580000: Epsilon: 0.9342, Avg Q-Learn: 29.8518, Avg Random: 0.1297
# Game 590000: Epsilon: 0.9333, Avg Q-Learn: 29.8422, Avg Random: 0.1387
# Game 600000: Epsilon: 0.9323, Avg Q-Learn: 29.9146, Avg Random: 0.1544
# Game 610000: Epsilon: 0.9314, Avg Q-Learn: 29.8762, Avg Random: 0.1896
# Game 620000: Epsilon: 0.9305, Avg Q-Learn: 29.8705, Avg Random: 0.1792
# Game 630000: Epsilon: 0.9296, Avg Q-Learn: 29.8841, Avg Random: 0.1155
# Game 640000: Epsilon: 0.9286, Avg Q-Learn: 29.9249, Avg Random: 0.1398
# Game 650000: Epsilon: 0.9277, Avg Q-Learn: 29.9917, Avg Random: 0.1503
# Game 660000: Epsilon: 0.9268, Avg Q-Learn: 30.0755, Avg Random: 0.1065
# Game 670000: Epsilon: 0.9258, Avg Q-Learn: 29.9755, Avg Random: 0.1597
# Game 680000: Epsilon: 0.9249, Avg Q-Learn: 29.9757, Avg Random: 0.1828
# Game 690000: Epsilon: 0.9240, Avg Q-Learn: 29.9278, Avg Random: 0.1512
# Game 700000: Epsilon: 0.9231, Avg Q-Learn: 29.9654, Avg Random: 0.1515
# Game 710000: Epsilon: 0.9221, Avg Q-Learn: 29.8672, Avg Random: 0.1912
# Game 720000: Epsilon: 0.9212, Avg Q-Learn: 30.0235, Avg Random: 0.1452
# Game 730000: Epsilon: 0.9203, Avg Q-Learn: 29.9609, Avg Random: 0.1191
# Game 740000: Epsilon: 0.9194, Avg Q-Learn: 30.0243, Avg Random: 0.1785
# Game 750000: Epsilon: 0.9185, Avg Q-Learn: 29.939, Avg Random: 0.1734
# Game 760000: Epsilon: 0.9175, Avg Q-Learn: 30.0022, Avg Random: 0.1466
# Game 770000: Epsilon: 0.9166, Avg Q-Learn: 29.9485, Avg Random: 0.1882
# Game 780000: Epsilon: 0.9157, Avg Q-Learn: 29.9489, Avg Random: 0.1545
# Game 790000: Epsilon: 0.9148, Avg Q-Learn: 29.9633, Avg Random: 0.1173
# Game 800000: Epsilon: 0.9139, Avg Q-Learn: 30.0636, Avg Random: 0.1226
# Game 810000: Epsilon: 0.9130, Avg Q-Learn: 30.0031, Avg Random: 0.1246
# Game 820000: Epsilon: 0.9121, Avg Q-Learn: 30.0367, Avg Random: 0.1824
# Game 830000: Epsilon: 0.9111, Avg Q-Learn: 30.0109, Avg Random: 0.1451
# Game 840000: Epsilon: 0.9102, Avg Q-Learn: 29.9745, Avg Random: 0.1772
# Game 850000: Epsilon: 0.9093, Avg Q-Learn: 30.0813, Avg Random: 0.1219
# Game 860000: Epsilon: 0.9084, Avg Q-Learn: 30.0277, Avg Random: 0.1609
# Game 870000: Epsilon: 0.9075, Avg Q-Learn: 30.1064, Avg Random: 0.1411
# Game 880000: Epsilon: 0.9066, Avg Q-Learn: 29.996, Avg Random: 0.1305
# Game 890000: Epsilon: 0.9057, Avg Q-Learn: 30.0297, Avg Random: 0.1661
# Game 900000: Epsilon: 0.9048, Avg Q-Learn: 29.9882, Avg Random: 0.1495
# Game 910000: Epsilon: 0.9039, Avg Q-Learn: 30.0866, Avg Random: 0.1583
# Game 920000: Epsilon: 0.9030, Avg Q-Learn: 30.1431, Avg Random: 0.1498
# Game 930000: Epsilon: 0.9021, Avg Q-Learn: 30.0951, Avg Random: 0.1171
# Game 940000: Epsilon: 0.9012, Avg Q-Learn: 30.0661, Avg Random: 0.1817
# Game 950000: Epsilon: 0.9003, Avg Q-Learn: 30.0552, Avg Random: 0.1824
# Game 960000: Epsilon: 0.8994, Avg Q-Learn: 30.0002, Avg Random: 0.1132
# Game 970000: Epsilon: 0.8985, Avg Q-Learn: 29.9828, Avg Random: 0.1788
# Game 980000: Epsilon: 0.8976, Avg Q-Learn: 30.0089, Avg Random: 0.1404
# Game 990000: Epsilon: 0.8967, Avg Q-Learn: 30.0309, Avg Random: 0.1974
# Game 1000000: Epsilon: 0.8958, Avg Q-Learn: 30.0511, Avg Random: 0.1176
# Game 1010000: Epsilon: 0.8949, Avg Q-Learn: 29.984, Avg Random: 0.1811
# Game 1020000: Epsilon: 0.8940, Avg Q-Learn: 29.9968, Avg Random: 0.1121
# Game 1030000: Epsilon: 0.8931, Avg Q-Learn: 30.0417, Avg Random: 0.1516
# Game 1040000: Epsilon: 0.8922, Avg Q-Learn: 29.973, Avg Random: 0.1314
# Game 1050000: Epsilon: 0.8913, Avg Q-Learn: 30.0214, Avg Random: 0.1439
# Game 1060000: Epsilon: 0.8904, Avg Q-Learn: 30.0316, Avg Random: 0.171
# Game 1070000: Epsilon: 0.8895, Avg Q-Learn: 30.1542, Avg Random: 0.1123
# Game 1080000: Epsilon: 0.8887, Avg Q-Learn: 30.0311, Avg Random: 0.1529
# Game 1090000: Epsilon: 0.8878, Avg Q-Learn: 29.9756, Avg Random: 0.2074
# Game 1100000: Epsilon: 0.8869, Avg Q-Learn: 30.1195, Avg Random: 0.1366
# Game 1110000: Epsilon: 0.8860, Avg Q-Learn: 30.007, Avg Random: 0.1755
# Game 1120000: Epsilon: 0.8851, Avg Q-Learn: 30.0656, Avg Random: 0.2041
# Game 1130000: Epsilon: 0.8842, Avg Q-Learn: 29.9917, Avg Random: 0.1783
# Game 1140000: Epsilon: 0.8833, Avg Q-Learn: 30.0201, Avg Random: 0.146
# Game 1150000: Epsilon: 0.8825, Avg Q-Learn: 29.9599, Avg Random: 0.2094
# Game 1160000: Epsilon: 0.8816, Avg Q-Learn: 30.0568, Avg Random: 0.196
# Game 1170000: Epsilon: 0.8807, Avg Q-Learn: 30.0595, Avg Random: 0.1612
# Game 1180000: Epsilon: 0.8798, Avg Q-Learn: 30.1258, Avg Random: 0.1557
# Game 1190000: Epsilon: 0.8789, Avg Q-Learn: 30.1158, Avg Random: 0.1525
# Game 1200000: Epsilon: 0.8781, Avg Q-Learn: 30.1774, Avg Random: 0.0694
# Game 1210000: Epsilon: 0.8772, Avg Q-Learn: 30.0908, Avg Random: 0.1731
# Game 1220000: Epsilon: 0.8763, Avg Q-Learn: 30.0745, Avg Random: 0.1654
# Game 1230000: Epsilon: 0.8754, Avg Q-Learn: 30.0748, Avg Random: 0.1658
# Game 1240000: Epsilon: 0.8745, Avg Q-Learn: 30.156, Avg Random: 0.1277
# Game 1250000: Epsilon: 0.8737, Avg Q-Learn: 30.0493, Avg Random: 0.1808
# Game 1260000: Epsilon: 0.8728, Avg Q-Learn: 30.064, Avg Random: 0.2093
# Game 1270000: Epsilon: 0.8719, Avg Q-Learn: 30.0939, Avg Random: 0.1289
# Game 1280000: Epsilon: 0.8711, Avg Q-Learn: 30.0734, Avg Random: 0.1724
# Game 1290000: Epsilon: 0.8702, Avg Q-Learn: 30.1802, Avg Random: 0.1175
# Game 1300000: Epsilon: 0.8693, Avg Q-Learn: 30.2053, Avg Random: 0.1615
# Game 1310000: Epsilon: 0.8684, Avg Q-Learn: 30.2254, Avg Random: 0.1132
# Game 1320000: Epsilon: 0.8676, Avg Q-Learn: 30.1144, Avg Random: 0.1254
# Game 1330000: Epsilon: 0.8667, Avg Q-Learn: 30.1189, Avg Random: 0.1723
# Game 1340000: Epsilon: 0.8658, Avg Q-Learn: 30.1562, Avg Random: 0.1503
# Game 1350000: Epsilon: 0.8650, Avg Q-Learn: 30.1929, Avg Random: 0.1486
# Game 1360000: Epsilon: 0.8641, Avg Q-Learn: 30.0741, Avg Random: 0.1769
# Game 1370000: Epsilon: 0.8633, Avg Q-Learn: 30.0955, Avg Random: 0.1503
# Game 1380000: Epsilon: 0.8624, Avg Q-Learn: 30.093, Avg Random: 0.1226
# Game 1390000: Epsilon: 0.8615, Avg Q-Learn: 30.145, Avg Random: 0.1537
# Game 1400000: Epsilon: 0.8607, Avg Q-Learn: 30.1432, Avg Random: 0.1691
# Game 1410000: Epsilon: 0.8598, Avg Q-Learn: 30.2298, Avg Random: 0.1118
# Game 1420000: Epsilon: 0.8589, Avg Q-Learn: 30.1924, Avg Random: 0.1448
# Game 1430000: Epsilon: 0.8581, Avg Q-Learn: 30.1584, Avg Random: 0.1043
# Game 1440000: Epsilon: 0.8572, Avg Q-Learn: 30.2676, Avg Random: 0.1533
# Game 1450000: Epsilon: 0.8564, Avg Q-Learn: 30.12, Avg Random: 0.148
# Game 1460000: Epsilon: 0.8555, Avg Q-Learn: 30.1066, Avg Random: 0.1459
# Game 1470000: Epsilon: 0.8547, Avg Q-Learn: 30.1147, Avg Random: 0.1674
# Game 1480000: Epsilon: 0.8538, Avg Q-Learn: 30.2051, Avg Random: 0.1635
# Game 1490000: Epsilon: 0.8530, Avg Q-Learn: 30.2367, Avg Random: 0.0826
# Game 1500000: Epsilon: 0.8521, Avg Q-Learn: 30.1043, Avg Random: 0.18
# Game 1510000: Epsilon: 0.8512, Avg Q-Learn: 30.1369, Avg Random: 0.1409
# Game 1520000: Epsilon: 0.8504, Avg Q-Learn: 30.1392, Avg Random: 0.1588
# Game 1530000: Epsilon: 0.8495, Avg Q-Learn: 30.2213, Avg Random: 0.1836
# Game 1540000: Epsilon: 0.8487, Avg Q-Learn: 30.1299, Avg Random: 0.163
# Game 1550000: Epsilon: 0.8479, Avg Q-Learn: 30.266, Avg Random: 0.1717
# Game 1560000: Epsilon: 0.8470, Avg Q-Learn: 30.1702, Avg Random: 0.099
# Game 1570000: Epsilon: 0.8462, Avg Q-Learn: 30.1433, Avg Random: 0.143
# Game 1580000: Epsilon: 0.8453, Avg Q-Learn: 30.1446, Avg Random: 0.1831
# Game 1590000: Epsilon: 0.8445, Avg Q-Learn: 30.1855, Avg Random: 0.1229
# Game 1600000: Epsilon: 0.8436, Avg Q-Learn: 30.2198, Avg Random: 0.1212
# Game 1610000: Epsilon: 0.8428, Avg Q-Learn: 30.2126, Avg Random: 0.1473
# Game 1620000: Epsilon: 0.8419, Avg Q-Learn: 30.167, Avg Random: 0.1604
# Game 1630000: Epsilon: 0.8411, Avg Q-Learn: 30.2247, Avg Random: 0.1256
# Game 1640000: Epsilon: 0.8403, Avg Q-Learn: 30.1919, Avg Random: 0.137
# Game 1650000: Epsilon: 0.8394, Avg Q-Learn: 30.1423, Avg Random: 0.1345
# Game 1660000: Epsilon: 0.8386, Avg Q-Learn: 30.1895, Avg Random: 0.1324
# Game 1670000: Epsilon: 0.8377, Avg Q-Learn: 30.2877, Avg Random: 0.119
# Game 1680000: Epsilon: 0.8369, Avg Q-Learn: 30.2187, Avg Random: 0.1448
# Game 1690000: Epsilon: 0.8361, Avg Q-Learn: 30.253, Avg Random: 0.1705
# Game 1700000: Epsilon: 0.8352, Avg Q-Learn: 30.2061, Avg Random: 0.2076
# Game 1710000: Epsilon: 0.8344, Avg Q-Learn: 30.1815, Avg Random: 0.1394
# Game 1720000: Epsilon: 0.8336, Avg Q-Learn: 30.3306, Avg Random: 0.1147
# Game 1730000: Epsilon: 0.8327, Avg Q-Learn: 30.2369, Avg Random: 0.2248
# Game 1740000: Epsilon: 0.8319, Avg Q-Learn: 30.297, Avg Random: 0.106
# Game 1750000: Epsilon: 0.8311, Avg Q-Learn: 30.214, Avg Random: 0.1765
# Game 1760000: Epsilon: 0.8302, Avg Q-Learn: 30.1313, Avg Random: 0.2022
# Game 1770000: Epsilon: 0.8294, Avg Q-Learn: 30.204, Avg Random: 0.1649
# Game 1780000: Epsilon: 0.8286, Avg Q-Learn: 30.3429, Avg Random: 0.1285
# Game 1790000: Epsilon: 0.8277, Avg Q-Learn: 30.232, Avg Random: 0.1614
# Game 1800000: Epsilon: 0.8269, Avg Q-Learn: 30.2496, Avg Random: 0.162
# Game 1810000: Epsilon: 0.8261, Avg Q-Learn: 30.2784, Avg Random: 0.1224
# Game 1820000: Epsilon: 0.8253, Avg Q-Learn: 30.2745, Avg Random: 0.1716
# Game 1830000: Epsilon: 0.8244, Avg Q-Learn: 30.1972, Avg Random: 0.1837
# Game 1840000: Epsilon: 0.8236, Avg Q-Learn: 30.2324, Avg Random: 0.1384
# Game 1850000: Epsilon: 0.8228, Avg Q-Learn: 30.2979, Avg Random: 0.1452
# Game 1860000: Epsilon: 0.8220, Avg Q-Learn: 30.1974, Avg Random: 0.2012
# Game 1870000: Epsilon: 0.8211, Avg Q-Learn: 30.1707, Avg Random: 0.1901
# Game 1880000: Epsilon: 0.8203, Avg Q-Learn: 30.3434, Avg Random: 0.1514
# Game 1890000: Epsilon: 0.8195, Avg Q-Learn: 30.2078, Avg Random: 0.1624
# Game 1900000: Epsilon: 0.8187, Avg Q-Learn: 30.3404, Avg Random: 0.1316
# Game 1910000: Epsilon: 0.8179, Avg Q-Learn: 30.3836, Avg Random: 0.1069
# Game 1920000: Epsilon: 0.8171, Avg Q-Learn: 30.2322, Avg Random: 0.1843
# Game 1930000: Epsilon: 0.8162, Avg Q-Learn: 30.2785, Avg Random: 0.1597
# Game 1940000: Epsilon: 0.8154, Avg Q-Learn: 30.2297, Avg Random: 0.1455
# Game 1950000: Epsilon: 0.8146, Avg Q-Learn: 30.3025, Avg Random: 0.1309
# Game 1960000: Epsilon: 0.8138, Avg Q-Learn: 30.3279, Avg Random: 0.1641
# Game 1970000: Epsilon: 0.8130, Avg Q-Learn: 30.3078, Avg Random: 0.1441
# Game 1980000: Epsilon: 0.8122, Avg Q-Learn: 30.264, Avg Random: 0.1719
# Game 1990000: Epsilon: 0.8114, Avg Q-Learn: 30.2278, Avg Random: 0.1719
# Game 2000000: Epsilon: 0.8105, Avg Q-Learn: 30.2857, Avg Random: 0.1106
# Game 2010000: Epsilon: 0.8097, Avg Q-Learn: 30.2913, Avg Random: 0.1904
# Game 2020000: Epsilon: 0.8089, Avg Q-Learn: 30.3438, Avg Random: 0.1219
# Game 2030000: Epsilon: 0.8081, Avg Q-Learn: 30.3749, Avg Random: 0.1577
# Game 2040000: Epsilon: 0.8073, Avg Q-Learn: 30.263, Avg Random: 0.1307
# Game 2050000: Epsilon: 0.8065, Avg Q-Learn: 30.2423, Avg Random: 0.2073
# Game 2060000: Epsilon: 0.8057, Avg Q-Learn: 30.3379, Avg Random: 0.203
# Game 2070000: Epsilon: 0.8049, Avg Q-Learn: 30.3777, Avg Random: 0.1221
# Game 2080000: Epsilon: 0.8041, Avg Q-Learn: 30.2639, Avg Random: 0.1565
# Game 2090000: Epsilon: 0.8033, Avg Q-Learn: 30.4183, Avg Random: 0.1469
# Game 2100000: Epsilon: 0.8025, Avg Q-Learn: 30.3113, Avg Random: 0.1411
# Game 2110000: Epsilon: 0.8017, Avg Q-Learn: 30.4005, Avg Random: 0.1619
# Game 2120000: Epsilon: 0.8009, Avg Q-Learn: 30.4014, Avg Random: 0.1215
# Game 2130000: Epsilon: 0.8001, Avg Q-Learn: 30.4024, Avg Random: 0.1005
# Game 2140000: Epsilon: 0.7993, Avg Q-Learn: 30.3192, Avg Random: 0.1673
# Game 2150000: Epsilon: 0.7985, Avg Q-Learn: 30.343, Avg Random: 0.1453
# Game 2160000: Epsilon: 0.7977, Avg Q-Learn: 30.3634, Avg Random: 0.1312
# Game 2170000: Epsilon: 0.7969, Avg Q-Learn: 30.3005, Avg Random: 0.1531
# Game 2180000: Epsilon: 0.7961, Avg Q-Learn: 30.3357, Avg Random: 0.1527
# Game 2190000: Epsilon: 0.7953, Avg Q-Learn: 30.4424, Avg Random: 0.1454
# Game 2200000: Epsilon: 0.7945, Avg Q-Learn: 30.3357, Avg Random: 0.1689
# Game 2210000: Epsilon: 0.7937, Avg Q-Learn: 30.3298, Avg Random: 0.1241
# Game 2220000: Epsilon: 0.7929, Avg Q-Learn: 30.2681, Avg Random: 0.1837
# Game 2230000: Epsilon: 0.7921, Avg Q-Learn: 30.4012, Avg Random: 0.1719
# Game 2240000: Epsilon: 0.7913, Avg Q-Learn: 30.3316, Avg Random: 0.1963
# Game 2250000: Epsilon: 0.7905, Avg Q-Learn: 30.4393, Avg Random: 0.1392
# Game 2260000: Epsilon: 0.7897, Avg Q-Learn: 30.4793, Avg Random: 0.1489
# Game 2270000: Epsilon: 0.7890, Avg Q-Learn: 30.3177, Avg Random: 0.2019
# Game 2280000: Epsilon: 0.7882, Avg Q-Learn: 30.3305, Avg Random: 0.1595
# Game 2290000: Epsilon: 0.7874, Avg Q-Learn: 30.367, Avg Random: 0.1643
# Game 2300000: Epsilon: 0.7866, Avg Q-Learn: 30.3119, Avg Random: 0.1715
# Game 2310000: Epsilon: 0.7858, Avg Q-Learn: 30.4271, Avg Random: 0.1139
# Game 2320000: Epsilon: 0.7850, Avg Q-Learn: 30.3521, Avg Random: 0.1806
# Game 2330000: Epsilon: 0.7842, Avg Q-Learn: 30.3517, Avg Random: 0.176
# Game 2340000: Epsilon: 0.7834, Avg Q-Learn: 30.41, Avg Random: 0.1448
# Game 2350000: Epsilon: 0.7827, Avg Q-Learn: 30.3292, Avg Random: 0.197
# Game 2360000: Epsilon: 0.7819, Avg Q-Learn: 30.3161, Avg Random: 0.1797
# Game 2370000: Epsilon: 0.7811, Avg Q-Learn: 30.3883, Avg Random: 0.166
# Game 2380000: Epsilon: 0.7803, Avg Q-Learn: 30.4145, Avg Random: 0.1755
# Game 2390000: Epsilon: 0.7795, Avg Q-Learn: 30.4156, Avg Random: 0.1344
# Game 2400000: Epsilon: 0.7788, Avg Q-Learn: 30.4085, Avg Random: 0.1931
# Game 2410000: Epsilon: 0.7780, Avg Q-Learn: 30.3434, Avg Random: 0.1826
# Game 2420000: Epsilon: 0.7772, Avg Q-Learn: 30.4731, Avg Random: 0.1514
# Game 2430000: Epsilon: 0.7764, Avg Q-Learn: 30.4159, Avg Random: 0.115
# Game 2440000: Epsilon: 0.7757, Avg Q-Learn: 30.4702, Avg Random: 0.1232
# Game 2450000: Epsilon: 0.7749, Avg Q-Learn: 30.4557, Avg Random: 0.1676
# Game 2460000: Epsilon: 0.7741, Avg Q-Learn: 30.4582, Avg Random: 0.1172
# Game 2470000: Epsilon: 0.7733, Avg Q-Learn: 30.3943, Avg Random: 0.1279
# Game 2480000: Epsilon: 0.7726, Avg Q-Learn: 30.4406, Avg Random: 0.1548
# Game 2490000: Epsilon: 0.7718, Avg Q-Learn: 30.4156, Avg Random: 0.1245
# Game 2500000: Epsilon: 0.7710, Avg Q-Learn: 30.4041, Avg Random: 0.1444
# Game 2510000: Epsilon: 0.7702, Avg Q-Learn: 30.4499, Avg Random: 0.1507
# Game 2520000: Epsilon: 0.7695, Avg Q-Learn: 30.4425, Avg Random: 0.1427
# Game 2530000: Epsilon: 0.7687, Avg Q-Learn: 30.4029, Avg Random: 0.1361
# Game 2540000: Epsilon: 0.7679, Avg Q-Learn: 30.4034, Avg Random: 0.1844
# Game 2550000: Epsilon: 0.7672, Avg Q-Learn: 30.4635, Avg Random: 0.1512
# Game 2560000: Epsilon: 0.7664, Avg Q-Learn: 30.4414, Avg Random: 0.1134
# Game 2570000: Epsilon: 0.7656, Avg Q-Learn: 30.4401, Avg Random: 0.1685
# Game 2580000: Epsilon: 0.7649, Avg Q-Learn: 30.477, Avg Random: 0.2004
# Game 2590000: Epsilon: 0.7641, Avg Q-Learn: 30.4021, Avg Random: 0.1735
# Game 2600000: Epsilon: 0.7633, Avg Q-Learn: 30.4027, Avg Random: 0.1239
# Game 2610000: Epsilon: 0.7626, Avg Q-Learn: 30.4385, Avg Random: 0.1657
# Game 2620000: Epsilon: 0.7618, Avg Q-Learn: 30.4209, Avg Random: 0.1341
# Game 2630000: Epsilon: 0.7611, Avg Q-Learn: 30.5372, Avg Random: 0.1289
# Game 2640000: Epsilon: 0.7603, Avg Q-Learn: 30.4479, Avg Random: 0.1397
# Game 2650000: Epsilon: 0.7595, Avg Q-Learn: 30.4563, Avg Random: 0.1528
# Game 2660000: Epsilon: 0.7588, Avg Q-Learn: 30.5142, Avg Random: 0.1311
# Game 2670000: Epsilon: 0.7580, Avg Q-Learn: 30.4761, Avg Random: 0.1656
# Game 2680000: Epsilon: 0.7573, Avg Q-Learn: 30.475, Avg Random: 0.1445
# Game 2690000: Epsilon: 0.7565, Avg Q-Learn: 30.4688, Avg Random: 0.1425
# Game 2700000: Epsilon: 0.7557, Avg Q-Learn: 30.4696, Avg Random: 0.1568
# Game 2710000: Epsilon: 0.7550, Avg Q-Learn: 30.4499, Avg Random: 0.2014
# Game 2720000: Epsilon: 0.7542, Avg Q-Learn: 30.4746, Avg Random: 0.1258
# Game 2730000: Epsilon: 0.7535, Avg Q-Learn: 30.5484, Avg Random: 0.1518
# Game 2740000: Epsilon: 0.7527, Avg Q-Learn: 30.4748, Avg Random: 0.1533
# Game 2750000: Epsilon: 0.7520, Avg Q-Learn: 30.4637, Avg Random: 0.1409
# Game 2760000: Epsilon: 0.7512, Avg Q-Learn: 30.5242, Avg Random: 0.1204
# Game 2770000: Epsilon: 0.7505, Avg Q-Learn: 30.5206, Avg Random: 0.1779
# Game 2780000: Epsilon: 0.7497, Avg Q-Learn: 30.4801, Avg Random: 0.1406
# Game 2790000: Epsilon: 0.7490, Avg Q-Learn: 30.475, Avg Random: 0.1434
# Game 2800000: Epsilon: 0.7482, Avg Q-Learn: 30.4673, Avg Random: 0.1457
# Game 2810000: Epsilon: 0.7475, Avg Q-Learn: 30.5728, Avg Random: 0.1338
# Game 2820000: Epsilon: 0.7467, Avg Q-Learn: 30.5184, Avg Random: 0.1524
# Game 2830000: Epsilon: 0.7460, Avg Q-Learn: 30.5286, Avg Random: 0.1529
# Game 2840000: Epsilon: 0.7452, Avg Q-Learn: 30.5315, Avg Random: 0.144
# Game 2850000: Epsilon: 0.7445, Avg Q-Learn: 30.5118, Avg Random: 0.1325
# Game 2860000: Epsilon: 0.7438, Avg Q-Learn: 30.5707, Avg Random: 0.1447
# Game 2870000: Epsilon: 0.7430, Avg Q-Learn: 30.5585, Avg Random: 0.1327
# Game 2880000: Epsilon: 0.7423, Avg Q-Learn: 30.5461, Avg Random: 0.1355
# Game 2890000: Epsilon: 0.7415, Avg Q-Learn: 30.5903, Avg Random: 0.1333
# Game 2900000: Epsilon: 0.7408, Avg Q-Learn: 30.5364, Avg Random: 0.1744
# Game 2910000: Epsilon: 0.7400, Avg Q-Learn: 30.5159, Avg Random: 0.136
# Game 2920000: Epsilon: 0.7393, Avg Q-Learn: 30.5407, Avg Random: 0.1255
# Game 2930000: Epsilon: 0.7386, Avg Q-Learn: 30.5816, Avg Random: 0.1451
# Game 2940000: Epsilon: 0.7378, Avg Q-Learn: 30.5596, Avg Random: 0.0904
# Game 2950000: Epsilon: 0.7371, Avg Q-Learn: 30.4811, Avg Random: 0.1556
# Game 2960000: Epsilon: 0.7363, Avg Q-Learn: 30.5393, Avg Random: 0.1242
# Game 2970000: Epsilon: 0.7356, Avg Q-Learn: 30.5095, Avg Random: 0.1318
# Game 2980000: Epsilon: 0.7349, Avg Q-Learn: 30.4787, Avg Random: 0.1981
# Game 2990000: Epsilon: 0.7341, Avg Q-Learn: 30.5774, Avg Random: 0.1208
# Game 3000000: Epsilon: 0.7334, Avg Q-Learn: 30.5378, Avg Random: 0.1595
# Game 3010000: Epsilon: 0.7327, Avg Q-Learn: 30.5869, Avg Random: 0.1268
# Game 3020000: Epsilon: 0.7319, Avg Q-Learn: 30.5086, Avg Random: 0.1727
# Game 3030000: Epsilon: 0.7312, Avg Q-Learn: 30.452, Avg Random: 0.185
# Game 3040000: Epsilon: 0.7305, Avg Q-Learn: 30.5346, Avg Random: 0.1429
# Game 3050000: Epsilon: 0.7298, Avg Q-Learn: 30.5195, Avg Random: 0.1324
# Game 3060000: Epsilon: 0.7290, Avg Q-Learn: 30.4839, Avg Random: 0.2042
# Game 3070000: Epsilon: 0.7283, Avg Q-Learn: 30.5611, Avg Random: 0.142
# Game 3080000: Epsilon: 0.7276, Avg Q-Learn: 30.4626, Avg Random: 0.2229
# Game 3090000: Epsilon: 0.7268, Avg Q-Learn: 30.5319, Avg Random: 0.1626
# Game 3100000: Epsilon: 0.7261, Avg Q-Learn: 30.4899, Avg Random: 0.1214
# Game 3110000: Epsilon: 0.7254, Avg Q-Learn: 30.546, Avg Random: 0.1351
# Game 3120000: Epsilon: 0.7247, Avg Q-Learn: 30.5621, Avg Random: 0.1719
# Game 3130000: Epsilon: 0.7239, Avg Q-Learn: 30.6487, Avg Random: 0.1569
# Game 3140000: Epsilon: 0.7232, Avg Q-Learn: 30.5168, Avg Random: 0.1891
# Game 3150000: Epsilon: 0.7225, Avg Q-Learn: 30.5564, Avg Random: 0.1563
# Game 3160000: Epsilon: 0.7218, Avg Q-Learn: 30.5488, Avg Random: 0.1564
# Game 3170000: Epsilon: 0.7210, Avg Q-Learn: 30.5849, Avg Random: 0.1175
# Game 3180000: Epsilon: 0.7203, Avg Q-Learn: 30.5078, Avg Random: 0.1326
# Game 3190000: Epsilon: 0.7196, Avg Q-Learn: 30.5516, Avg Random: 0.1328
# Game 3200000: Epsilon: 0.7189, Avg Q-Learn: 30.5942, Avg Random: 0.1469
# Game 3210000: Epsilon: 0.7182, Avg Q-Learn: 30.6243, Avg Random: 0.1535
# Game 3220000: Epsilon: 0.7175, Avg Q-Learn: 30.5875, Avg Random: 0.1778
# Game 3230000: Epsilon: 0.7167, Avg Q-Learn: 30.5213, Avg Random: 0.1746
# Game 3240000: Epsilon: 0.7160, Avg Q-Learn: 30.6167, Avg Random: 0.1578
# Game 3250000: Epsilon: 0.7153, Avg Q-Learn: 30.5493, Avg Random: 0.1802
# Game 3260000: Epsilon: 0.7146, Avg Q-Learn: 30.5602, Avg Random: 0.1857
# Game 3270000: Epsilon: 0.7139, Avg Q-Learn: 30.5858, Avg Random: 0.1286
# Game 3280000: Epsilon: 0.7132, Avg Q-Learn: 30.6679, Avg Random: 0.1544
# Game 3290000: Epsilon: 0.7124, Avg Q-Learn: 30.5882, Avg Random: 0.154
# Game 3300000: Epsilon: 0.7117, Avg Q-Learn: 30.6364, Avg Random: 0.1275
# Game 3310000: Epsilon: 0.7110, Avg Q-Learn: 30.6457, Avg Random: 0.1306
# Game 3320000: Epsilon: 0.7103, Avg Q-Learn: 30.6355, Avg Random: 0.1875
# Game 3330000: Epsilon: 0.7096, Avg Q-Learn: 30.5551, Avg Random: 0.1495
# Game 3340000: Epsilon: 0.7089, Avg Q-Learn: 30.5878, Avg Random: 0.1491
# Game 3350000: Epsilon: 0.7082, Avg Q-Learn: 30.6002, Avg Random: 0.1555
# Game 3360000: Epsilon: 0.7075, Avg Q-Learn: 30.6233, Avg Random: 0.1741
# Game 3370000: Epsilon: 0.7068, Avg Q-Learn: 30.5884, Avg Random: 0.1626
# Game 3380000: Epsilon: 0.7061, Avg Q-Learn: 30.6667, Avg Random: 0.1783
# Game 3390000: Epsilon: 0.7054, Avg Q-Learn: 30.6583, Avg Random: 0.1816
# Game 3400000: Epsilon: 0.7047, Avg Q-Learn: 30.5899, Avg Random: 0.1467
# Game 3410000: Epsilon: 0.7039, Avg Q-Learn: 30.6432, Avg Random: 0.1424
# Game 3420000: Epsilon: 0.7032, Avg Q-Learn: 30.5874, Avg Random: 0.1341
# Game 3430000: Epsilon: 0.7025, Avg Q-Learn: 30.7058, Avg Random: 0.1102
# Game 3440000: Epsilon: 0.7018, Avg Q-Learn: 30.6279, Avg Random: 0.1566
# Game 3450000: Epsilon: 0.7011, Avg Q-Learn: 30.677, Avg Random: 0.1148
# Game 3460000: Epsilon: 0.7004, Avg Q-Learn: 30.6711, Avg Random: 0.1362
# Game 3470000: Epsilon: 0.6997, Avg Q-Learn: 30.5726, Avg Random: 0.1412
# Game 3480000: Epsilon: 0.6990, Avg Q-Learn: 30.6964, Avg Random: 0.1432
# Game 3490000: Epsilon: 0.6983, Avg Q-Learn: 30.7078, Avg Random: 0.1589
# Game 3500000: Epsilon: 0.6976, Avg Q-Learn: 30.676, Avg Random: 0.1875
# Game 3510000: Epsilon: 0.6969, Avg Q-Learn: 30.6405, Avg Random: 0.1147
# Game 3520000: Epsilon: 0.6962, Avg Q-Learn: 30.6907, Avg Random: 0.176
# Game 3530000: Epsilon: 0.6956, Avg Q-Learn: 30.6568, Avg Random: 0.1011
# Game 3540000: Epsilon: 0.6949, Avg Q-Learn: 30.6216, Avg Random: 0.152
# Game 3550000: Epsilon: 0.6942, Avg Q-Learn: 30.6401, Avg Random: 0.1618
# Game 3560000: Epsilon: 0.6935, Avg Q-Learn: 30.655, Avg Random: 0.116
# Game 3570000: Epsilon: 0.6928, Avg Q-Learn: 30.6336, Avg Random: 0.1664
# Game 3580000: Epsilon: 0.6921, Avg Q-Learn: 30.7007, Avg Random: 0.1716
# Game 3590000: Epsilon: 0.6914, Avg Q-Learn: 30.6763, Avg Random: 0.1468
# Game 3600000: Epsilon: 0.6907, Avg Q-Learn: 30.6088, Avg Random: 0.1463
# Game 3610000: Epsilon: 0.6900, Avg Q-Learn: 30.6726, Avg Random: 0.1711
# Game 3620000: Epsilon: 0.6893, Avg Q-Learn: 30.7391, Avg Random: 0.1314
# Game 3630000: Epsilon: 0.6886, Avg Q-Learn: 30.7674, Avg Random: 0.1503
# Game 3640000: Epsilon: 0.6879, Avg Q-Learn: 30.7428, Avg Random: 0.1266
# Game 3650000: Epsilon: 0.6873, Avg Q-Learn: 30.698, Avg Random: 0.0864
# Game 3660000: Epsilon: 0.6866, Avg Q-Learn: 30.6925, Avg Random: 0.1528
# Game 3670000: Epsilon: 0.6859, Avg Q-Learn: 30.6296, Avg Random: 0.1514
# Game 3680000: Epsilon: 0.6852, Avg Q-Learn: 30.6521, Avg Random: 0.1705
# Game 3690000: Epsilon: 0.6845, Avg Q-Learn: 30.7342, Avg Random: 0.1155
# Game 3700000: Epsilon: 0.6838, Avg Q-Learn: 30.5635, Avg Random: 0.1459
# Game 3710000: Epsilon: 0.6831, Avg Q-Learn: 30.6624, Avg Random: 0.1965
# Game 3720000: Epsilon: 0.6825, Avg Q-Learn: 30.7358, Avg Random: 0.1728
# Game 3730000: Epsilon: 0.6818, Avg Q-Learn: 30.7868, Avg Random: 0.0988
# Game 3740000: Epsilon: 0.6811, Avg Q-Learn: 30.667, Avg Random: 0.1576
# Game 3750000: Epsilon: 0.6804, Avg Q-Learn: 30.6226, Avg Random: 0.1643
# Game 3760000: Epsilon: 0.6797, Avg Q-Learn: 30.7602, Avg Random: 0.1138
# Game 3770000: Epsilon: 0.6791, Avg Q-Learn: 30.6802, Avg Random: 0.1309
# Game 3780000: Epsilon: 0.6784, Avg Q-Learn: 30.6875, Avg Random: 0.1719
# Game 3790000: Epsilon: 0.6777, Avg Q-Learn: 30.7163, Avg Random: 0.0936
# Game 3800000: Epsilon: 0.6770, Avg Q-Learn: 30.7207, Avg Random: 0.1134
# Game 3810000: Epsilon: 0.6763, Avg Q-Learn: 30.724, Avg Random: 0.1178
# Game 3820000: Epsilon: 0.6757, Avg Q-Learn: 30.7214, Avg Random: 0.1487
# Game 3830000: Epsilon: 0.6750, Avg Q-Learn: 30.7408, Avg Random: 0.1343
# Game 3840000: Epsilon: 0.6743, Avg Q-Learn: 30.6704, Avg Random: 0.1334
# Game 3850000: Epsilon: 0.6736, Avg Q-Learn: 30.701, Avg Random: 0.1466
# Game 3860000: Epsilon: 0.6730, Avg Q-Learn: 30.6581, Avg Random: 0.1522
# Game 3870000: Epsilon: 0.6723, Avg Q-Learn: 30.6421, Avg Random: 0.1811
# Game 3880000: Epsilon: 0.6716, Avg Q-Learn: 30.833, Avg Random: 0.1273
# Game 3890000: Epsilon: 0.6710, Avg Q-Learn: 30.7544, Avg Random: 0.1186
# Game 3900000: Epsilon: 0.6703, Avg Q-Learn: 30.7615, Avg Random: 0.1374
# Game 3910000: Epsilon: 0.6696, Avg Q-Learn: 30.8179, Avg Random: 0.1417
# Game 3920000: Epsilon: 0.6689, Avg Q-Learn: 30.7788, Avg Random: 0.1554
# Game 3930000: Epsilon: 0.6683, Avg Q-Learn: 30.7996, Avg Random: 0.1142
# Game 3940000: Epsilon: 0.6676, Avg Q-Learn: 30.7203, Avg Random: 0.1225
# Game 3950000: Epsilon: 0.6669, Avg Q-Learn: 30.7805, Avg Random: 0.1384
# Game 3960000: Epsilon: 0.6663, Avg Q-Learn: 30.6213, Avg Random: 0.1804
# Game 3970000: Epsilon: 0.6656, Avg Q-Learn: 30.7706, Avg Random: 0.1655
# Game 3980000: Epsilon: 0.6649, Avg Q-Learn: 30.7116, Avg Random: 0.1638
# Game 3990000: Epsilon: 0.6643, Avg Q-Learn: 30.7146, Avg Random: 0.1434
# Game 4000000: Epsilon: 0.6636, Avg Q-Learn: 30.7415, Avg Random: 0.156
# Game 4010000: Epsilon: 0.6630, Avg Q-Learn: 30.7374, Avg Random: 0.1462
# Game 4020000: Epsilon: 0.6623, Avg Q-Learn: 30.8146, Avg Random: 0.1298
# Game 4030000: Epsilon: 0.6616, Avg Q-Learn: 30.7314, Avg Random: 0.1814
# Game 4040000: Epsilon: 0.6610, Avg Q-Learn: 30.746, Avg Random: 0.1412
# Game 4050000: Epsilon: 0.6603, Avg Q-Learn: 30.8115, Avg Random: 0.1404
# Game 4060000: Epsilon: 0.6596, Avg Q-Learn: 30.8227, Avg Random: 0.096
# Game 4070000: Epsilon: 0.6590, Avg Q-Learn: 30.7368, Avg Random: 0.1244
# Game 4080000: Epsilon: 0.6583, Avg Q-Learn: 30.8537, Avg Random: 0.0739
# Game 4090000: Epsilon: 0.6577, Avg Q-Learn: 30.8203, Avg Random: 0.1329
# Game 4100000: Epsilon: 0.6570, Avg Q-Learn: 30.7973, Avg Random: 0.1275
# Game 4110000: Epsilon: 0.6564, Avg Q-Learn: 30.7404, Avg Random: 0.1362
# Game 4120000: Epsilon: 0.6557, Avg Q-Learn: 30.7674, Avg Random: 0.1644
# Game 4130000: Epsilon: 0.6550, Avg Q-Learn: 30.7965, Avg Random: 0.1675
# Game 4140000: Epsilon: 0.6544, Avg Q-Learn: 30.7705, Avg Random: 0.1576
# Game 4150000: Epsilon: 0.6537, Avg Q-Learn: 30.8503, Avg Random: 0.145
# Game 4160000: Epsilon: 0.6531, Avg Q-Learn: 30.834, Avg Random: 0.1314
# Game 4170000: Epsilon: 0.6524, Avg Q-Learn: 30.9138, Avg Random: 0.1217
# Game 4180000: Epsilon: 0.6518, Avg Q-Learn: 30.8558, Avg Random: 0.1546
# Game 4190000: Epsilon: 0.6511, Avg Q-Learn: 30.7195, Avg Random: 0.1764
# Game 4200000: Epsilon: 0.6505, Avg Q-Learn: 30.7688, Avg Random: 0.1221
# Game 4210000: Epsilon: 0.6498, Avg Q-Learn: 30.8259, Avg Random: 0.1154
# Game 4220000: Epsilon: 0.6492, Avg Q-Learn: 30.7865, Avg Random: 0.1371
# Game 4230000: Epsilon: 0.6485, Avg Q-Learn: 30.7616, Avg Random: 0.116
# Game 4240000: Epsilon: 0.6479, Avg Q-Learn: 30.877, Avg Random: 0.1584
# Game 4250000: Epsilon: 0.6472, Avg Q-Learn: 30.8561, Avg Random: 0.1048
# Game 4260000: Epsilon: 0.6466, Avg Q-Learn: 30.7692, Avg Random: 0.1727
# Game 4270000: Epsilon: 0.6459, Avg Q-Learn: 30.7622, Avg Random: 0.1698
# Game 4280000: Epsilon: 0.6453, Avg Q-Learn: 30.89, Avg Random: 0.1167
# Game 4290000: Epsilon: 0.6446, Avg Q-Learn: 30.9077, Avg Random: 0.1254
# Game 4300000: Epsilon: 0.6440, Avg Q-Learn: 30.8414, Avg Random: 0.164
# Game 4310000: Epsilon: 0.6434, Avg Q-Learn: 30.7638, Avg Random: 0.175
# Game 4320000: Epsilon: 0.6427, Avg Q-Learn: 30.8703, Avg Random: 0.1268
# Game 4330000: Epsilon: 0.6421, Avg Q-Learn: 30.834, Avg Random: 0.1491
# Game 4340000: Epsilon: 0.6414, Avg Q-Learn: 30.8512, Avg Random: 0.1507
# Game 4350000: Epsilon: 0.6408, Avg Q-Learn: 30.7944, Avg Random: 0.1539
# Game 4360000: Epsilon: 0.6402, Avg Q-Learn: 30.791, Avg Random: 0.1581
# Game 4370000: Epsilon: 0.6395, Avg Q-Learn: 30.8415, Avg Random: 0.186
# Game 4380000: Epsilon: 0.6389, Avg Q-Learn: 30.7707, Avg Random: 0.137
# Game 4390000: Epsilon: 0.6382, Avg Q-Learn: 30.8732, Avg Random: 0.1304
# Game 4400000: Epsilon: 0.6376, Avg Q-Learn: 30.8458, Avg Random: 0.1263
# Game 4410000: Epsilon: 0.6370, Avg Q-Learn: 30.834, Avg Random: 0.1001
# Game 4420000: Epsilon: 0.6363, Avg Q-Learn: 30.8239, Avg Random: 0.1114
# Game 4430000: Epsilon: 0.6357, Avg Q-Learn: 30.7886, Avg Random: 0.1807
# Game 4440000: Epsilon: 0.6351, Avg Q-Learn: 30.8969, Avg Random: 0.1467
# Game 4450000: Epsilon: 0.6344, Avg Q-Learn: 30.7311, Avg Random: 0.1442
# Game 4460000: Epsilon: 0.6338, Avg Q-Learn: 30.9225, Avg Random: 0.1038
# Game 4470000: Epsilon: 0.6331, Avg Q-Learn: 30.8466, Avg Random: 0.1437
# Game 4480000: Epsilon: 0.6325, Avg Q-Learn: 30.8339, Avg Random: 0.1415
# Game 4490000: Epsilon: 0.6319, Avg Q-Learn: 30.8668, Avg Random: 0.1426
# Game 4500000: Epsilon: 0.6313, Avg Q-Learn: 30.8812, Avg Random: 0.1228
# Game 4510000: Epsilon: 0.6306, Avg Q-Learn: 30.8622, Avg Random: 0.1771
# Game 4520000: Epsilon: 0.6300, Avg Q-Learn: 30.8557, Avg Random: 0.1735
# Game 4530000: Epsilon: 0.6294, Avg Q-Learn: 30.8116, Avg Random: 0.1427
# Game 4540000: Epsilon: 0.6287, Avg Q-Learn: 30.8717, Avg Random: 0.0866
# Game 4550000: Epsilon: 0.6281, Avg Q-Learn: 30.88, Avg Random: 0.1493
# Game 4560000: Epsilon: 0.6275, Avg Q-Learn: 30.8537, Avg Random: 0.1454
# Game 4570000: Epsilon: 0.6268, Avg Q-Learn: 30.8795, Avg Random: 0.1363
# Game 4580000: Epsilon: 0.6262, Avg Q-Learn: 30.8842, Avg Random: 0.1214
# Game 4590000: Epsilon: 0.6256, Avg Q-Learn: 30.8859, Avg Random: 0.1032
# Game 4600000: Epsilon: 0.6250, Avg Q-Learn: 30.9532, Avg Random: 0.156
# Game 4610000: Epsilon: 0.6243, Avg Q-Learn: 30.924, Avg Random: 0.1556
# Game 4620000: Epsilon: 0.6237, Avg Q-Learn: 30.9459, Avg Random: 0.1444
# Game 4630000: Epsilon: 0.6231, Avg Q-Learn: 30.8922, Avg Random: 0.1235
# Game 4640000: Epsilon: 0.6225, Avg Q-Learn: 30.7893, Avg Random: 0.1541
# Game 4650000: Epsilon: 0.6219, Avg Q-Learn: 30.8761, Avg Random: 0.1548
# Game 4660000: Epsilon: 0.6212, Avg Q-Learn: 30.8217, Avg Random: 0.1449
# Game 4670000: Epsilon: 0.6206, Avg Q-Learn: 30.8986, Avg Random: 0.1364
# Game 4680000: Epsilon: 0.6200, Avg Q-Learn: 30.9009, Avg Random: 0.1148
# Game 4690000: Epsilon: 0.6194, Avg Q-Learn: 30.9054, Avg Random: 0.1314
# Game 4700000: Epsilon: 0.6188, Avg Q-Learn: 30.9059, Avg Random: 0.1341
# Game 4710000: Epsilon: 0.6181, Avg Q-Learn: 30.9519, Avg Random: 0.1025
# Game 4720000: Epsilon: 0.6175, Avg Q-Learn: 30.9691, Avg Random: 0.1832
# Game 4730000: Epsilon: 0.6169, Avg Q-Learn: 30.9035, Avg Random: 0.1434
# Game 4740000: Epsilon: 0.6163, Avg Q-Learn: 30.8913, Avg Random: 0.1193
# Game 4750000: Epsilon: 0.6157, Avg Q-Learn: 30.9292, Avg Random: 0.1257
# Game 4760000: Epsilon: 0.6151, Avg Q-Learn: 30.9039, Avg Random: 0.186
# Game 4770000: Epsilon: 0.6144, Avg Q-Learn: 30.9408, Avg Random: 0.1064
# Game 4780000: Epsilon: 0.6138, Avg Q-Learn: 30.9876, Avg Random: 0.0917
# Game 4790000: Epsilon: 0.6132, Avg Q-Learn: 31.0001, Avg Random: 0.102
# Game 4800000: Epsilon: 0.6126, Avg Q-Learn: 30.9415, Avg Random: 0.1284
# Game 4810000: Epsilon: 0.6120, Avg Q-Learn: 30.9511, Avg Random: 0.1438
# Game 4820000: Epsilon: 0.6114, Avg Q-Learn: 30.91, Avg Random: 0.1367
# Game 4830000: Epsilon: 0.6108, Avg Q-Learn: 30.8211, Avg Random: 0.1756
# Game 4840000: Epsilon: 0.6102, Avg Q-Learn: 30.9679, Avg Random: 0.1472
# Game 4850000: Epsilon: 0.6095, Avg Q-Learn: 30.9057, Avg Random: 0.1596
# Game 4860000: Epsilon: 0.6089, Avg Q-Learn: 30.9863, Avg Random: 0.1188
# Game 4870000: Epsilon: 0.6083, Avg Q-Learn: 30.8802, Avg Random: 0.1259
# Game 4880000: Epsilon: 0.6077, Avg Q-Learn: 30.9461, Avg Random: 0.136
# Game 4890000: Epsilon: 0.6071, Avg Q-Learn: 30.929, Avg Random: 0.1199
# Game 4900000: Epsilon: 0.6065, Avg Q-Learn: 30.975, Avg Random: 0.1466
# Game 4910000: Epsilon: 0.6059, Avg Q-Learn: 30.9455, Avg Random: 0.1298
# Game 4920000: Epsilon: 0.6053, Avg Q-Learn: 30.8819, Avg Random: 0.1384
# Game 4930000: Epsilon: 0.6047, Avg Q-Learn: 31.0007, Avg Random: 0.1282
# Game 4940000: Epsilon: 0.6041, Avg Q-Learn: 30.9857, Avg Random: 0.1326
# Game 4950000: Epsilon: 0.6035, Avg Q-Learn: 30.9282, Avg Random: 0.1467
# Game 4960000: Epsilon: 0.6029, Avg Q-Learn: 30.9105, Avg Random: 0.152
# Game 4970000: Epsilon: 0.6023, Avg Q-Learn: 31.0273, Avg Random: 0.1228
# Game 4980000: Epsilon: 0.6017, Avg Q-Learn: 30.9884, Avg Random: 0.1183
# Game 4990000: Epsilon: 0.6011, Avg Q-Learn: 30.9421, Avg Random: 0.1479
# Game 5000000: Epsilon: 0.6005, Avg Q-Learn: 30.9227, Avg Random: 0.1837
# Game 5010000: Epsilon: 0.5999, Avg Q-Learn: 30.9428, Avg Random: 0.1226
# Game 5020000: Epsilon: 0.5993, Avg Q-Learn: 30.9447, Avg Random: 0.1613
# Game 5030000: Epsilon: 0.5987, Avg Q-Learn: 30.9234, Avg Random: 0.1323
# Game 5040000: Epsilon: 0.5981, Avg Q-Learn: 31.0101, Avg Random: 0.1487
# Game 5050000: Epsilon: 0.5975, Avg Q-Learn: 31.0502, Avg Random: 0.1276
# Game 5060000: Epsilon: 0.5969, Avg Q-Learn: 30.9782, Avg Random: 0.1342
# Game 5070000: Epsilon: 0.5963, Avg Q-Learn: 31.0558, Avg Random: 0.1542
# Game 5080000: Epsilon: 0.5957, Avg Q-Learn: 30.9553, Avg Random: 0.1557
# Game 5090000: Epsilon: 0.5951, Avg Q-Learn: 30.9299, Avg Random: 0.1247
# Game 5100000: Epsilon: 0.5945, Avg Q-Learn: 30.9423, Avg Random: 0.1684
# Game 5110000: Epsilon: 0.5939, Avg Q-Learn: 31.0238, Avg Random: 0.108
# Game 5120000: Epsilon: 0.5933, Avg Q-Learn: 31.0237, Avg Random: 0.0986
# Game 5130000: Epsilon: 0.5927, Avg Q-Learn: 31.0178, Avg Random: 0.1432
# Game 5140000: Epsilon: 0.5921, Avg Q-Learn: 31.0292, Avg Random: 0.139
# Game 5150000: Epsilon: 0.5915, Avg Q-Learn: 31.067, Avg Random: 0.1396
# Game 5160000: Epsilon: 0.5909, Avg Q-Learn: 31.0407, Avg Random: 0.1293
# Game 5170000: Epsilon: 0.5903, Avg Q-Learn: 30.9788, Avg Random: 0.153
# Game 5180000: Epsilon: 0.5898, Avg Q-Learn: 30.9578, Avg Random: 0.123
# Game 5190000: Epsilon: 0.5892, Avg Q-Learn: 31.0237, Avg Random: 0.112
# Game 5200000: Epsilon: 0.5886, Avg Q-Learn: 30.9627, Avg Random: 0.1285
# Game 5210000: Epsilon: 0.5880, Avg Q-Learn: 31.068, Avg Random: 0.1152
# Game 5220000: Epsilon: 0.5874, Avg Q-Learn: 31.0351, Avg Random: 0.1292
# Game 5230000: Epsilon: 0.5868, Avg Q-Learn: 31.0945, Avg Random: 0.1492
# Game 5240000: Epsilon: 0.5862, Avg Q-Learn: 31.1188, Avg Random: 0.1265
# Game 5250000: Epsilon: 0.5856, Avg Q-Learn: 31.0309, Avg Random: 0.1354
# Game 5260000: Epsilon: 0.5851, Avg Q-Learn: 30.9801, Avg Random: 0.156
# Game 5270000: Epsilon: 0.5845, Avg Q-Learn: 31.0027, Avg Random: 0.1416
# Game 5280000: Epsilon: 0.5839, Avg Q-Learn: 31.0159, Avg Random: 0.1678
# Game 5290000: Epsilon: 0.5833, Avg Q-Learn: 31.0267, Avg Random: 0.1266
# Game 5300000: Epsilon: 0.5827, Avg Q-Learn: 30.9856, Avg Random: 0.1391
# Game 5310000: Epsilon: 0.5821, Avg Q-Learn: 30.9983, Avg Random: 0.1327
# Game 5320000: Epsilon: 0.5816, Avg Q-Learn: 31.0024, Avg Random: 0.1404
# Game 5330000: Epsilon: 0.5810, Avg Q-Learn: 30.9188, Avg Random: 0.1892
# Game 5340000: Epsilon: 0.5804, Avg Q-Learn: 31.0377, Avg Random: 0.1404
# Game 5350000: Epsilon: 0.5798, Avg Q-Learn: 31.018, Avg Random: 0.1019
# Game 5360000: Epsilon: 0.5792, Avg Q-Learn: 31.0901, Avg Random: 0.1176
# Game 5370000: Epsilon: 0.5787, Avg Q-Learn: 31.0216, Avg Random: 0.124
# Game 5380000: Epsilon: 0.5781, Avg Q-Learn: 31.0189, Avg Random: 0.1234
# Game 5390000: Epsilon: 0.5775, Avg Q-Learn: 31.0271, Avg Random: 0.1164
# Game 5400000: Epsilon: 0.5769, Avg Q-Learn: 31.0145, Avg Random: 0.0789
# Game 5410000: Epsilon: 0.5763, Avg Q-Learn: 31.0521, Avg Random: 0.1328
# Game 5420000: Epsilon: 0.5758, Avg Q-Learn: 31.0846, Avg Random: 0.1501
# Game 5430000: Epsilon: 0.5752, Avg Q-Learn: 31.0668, Avg Random: 0.1509
# Game 5440000: Epsilon: 0.5746, Avg Q-Learn: 31.0696, Avg Random: 0.1245
# Game 5450000: Epsilon: 0.5740, Avg Q-Learn: 31.0518, Avg Random: 0.1158
# Game 5460000: Epsilon: 0.5735, Avg Q-Learn: 30.9968, Avg Random: 0.1196
# Game 5470000: Epsilon: 0.5729, Avg Q-Learn: 31.0462, Avg Random: 0.13
# Game 5480000: Epsilon: 0.5723, Avg Q-Learn: 31.0762, Avg Random: 0.1523
# Game 5490000: Epsilon: 0.5718, Avg Q-Learn: 30.9586, Avg Random: 0.1498
# Game 5500000: Epsilon: 0.5712, Avg Q-Learn: 31.139, Avg Random: 0.1504
# Game 5510000: Epsilon: 0.5706, Avg Q-Learn: 31.0174, Avg Random: 0.1111
# Game 5520000: Epsilon: 0.5700, Avg Q-Learn: 31.0501, Avg Random: 0.1211
# Game 5530000: Epsilon: 0.5695, Avg Q-Learn: 31.0594, Avg Random: 0.1206
# Game 5540000: Epsilon: 0.5689, Avg Q-Learn: 31.144, Avg Random: 0.1526
# Game 5550000: Epsilon: 0.5683, Avg Q-Learn: 31.1158, Avg Random: 0.1423
# Game 5560000: Epsilon: 0.5678, Avg Q-Learn: 31.1401, Avg Random: 0.1288
# Game 5570000: Epsilon: 0.5672, Avg Q-Learn: 31.0197, Avg Random: 0.1212
# Game 5580000: Epsilon: 0.5666, Avg Q-Learn: 31.1347, Avg Random: 0.1427
# Game 5590000: Epsilon: 0.5661, Avg Q-Learn: 31.095, Avg Random: 0.1407
# Game 5600000: Epsilon: 0.5655, Avg Q-Learn: 31.0762, Avg Random: 0.1408
# Game 5610000: Epsilon: 0.5649, Avg Q-Learn: 31.0424, Avg Random: 0.1649
# Game 5620000: Epsilon: 0.5644, Avg Q-Learn: 31.1216, Avg Random: 0.1038
# Game 5630000: Epsilon: 0.5638, Avg Q-Learn: 31.0775, Avg Random: 0.143
# Game 5640000: Epsilon: 0.5632, Avg Q-Learn: 31.1004, Avg Random: 0.1313
# Game 5650000: Epsilon: 0.5627, Avg Q-Learn: 31.1498, Avg Random: 0.1373
# Game 5660000: Epsilon: 0.5621, Avg Q-Learn: 31.0444, Avg Random: 0.1231
# Game 5670000: Epsilon: 0.5616, Avg Q-Learn: 31.0809, Avg Random: 0.121
# Game 5680000: Epsilon: 0.5610, Avg Q-Learn: 31.0284, Avg Random: 0.168
# Game 5690000: Epsilon: 0.5604, Avg Q-Learn: 31.1375, Avg Random: 0.1138
# Game 5700000: Epsilon: 0.5599, Avg Q-Learn: 31.0824, Avg Random: 0.1122
# Game 5710000: Epsilon: 0.5593, Avg Q-Learn: 31.0923, Avg Random: 0.1692
# Game 5720000: Epsilon: 0.5588, Avg Q-Learn: 31.1067, Avg Random: 0.1425
# Game 5730000: Epsilon: 0.5582, Avg Q-Learn: 31.095, Avg Random: 0.1314
# Game 5740000: Epsilon: 0.5576, Avg Q-Learn: 31.1353, Avg Random: 0.1201
# Game 5750000: Epsilon: 0.5571, Avg Q-Learn: 31.1127, Avg Random: 0.1371
# Game 5760000: Epsilon: 0.5565, Avg Q-Learn: 31.1497, Avg Random: 0.1379
# Game 5770000: Epsilon: 0.5560, Avg Q-Learn: 31.123, Avg Random: 0.0889
# Game 5780000: Epsilon: 0.5554, Avg Q-Learn: 31.1355, Avg Random: 0.1586
# Game 5790000: Epsilon: 0.5549, Avg Q-Learn: 31.0799, Avg Random: 0.1433
# Game 5800000: Epsilon: 0.5543, Avg Q-Learn: 31.0932, Avg Random: 0.1161
# Game 5810000: Epsilon: 0.5537, Avg Q-Learn: 31.1873, Avg Random: 0.1425
# Game 5820000: Epsilon: 0.5532, Avg Q-Learn: 31.0927, Avg Random: 0.1256
# Game 5830000: Epsilon: 0.5526, Avg Q-Learn: 31.1245, Avg Random: 0.1369
# Game 5840000: Epsilon: 0.5521, Avg Q-Learn: 31.1434, Avg Random: 0.1026
# Game 5850000: Epsilon: 0.5515, Avg Q-Learn: 31.1596, Avg Random: 0.1062
# Game 5860000: Epsilon: 0.5510, Avg Q-Learn: 31.0497, Avg Random: 0.1309
# Game 5870000: Epsilon: 0.5504, Avg Q-Learn: 31.1874, Avg Random: 0.1214
# Game 5880000: Epsilon: 0.5499, Avg Q-Learn: 31.1436, Avg Random: 0.1093
# Game 5890000: Epsilon: 0.5493, Avg Q-Learn: 31.1527, Avg Random: 0.1209
# Game 5900000: Epsilon: 0.5488, Avg Q-Learn: 31.1619, Avg Random: 0.1566
# Game 5910000: Epsilon: 0.5482, Avg Q-Learn: 31.218, Avg Random: 0.0898
# Game 5920000: Epsilon: 0.5477, Avg Q-Learn: 31.1458, Avg Random: 0.1356
# Game 5930000: Epsilon: 0.5471, Avg Q-Learn: 31.0915, Avg Random: 0.1299
# Game 5940000: Epsilon: 0.5466, Avg Q-Learn: 31.1507, Avg Random: 0.12
# Game 5950000: Epsilon: 0.5460, Avg Q-Learn: 31.1743, Avg Random: 0.1764
# Game 5960000: Epsilon: 0.5455, Avg Q-Learn: 31.1478, Avg Random: 0.1542
# Game 5970000: Epsilon: 0.5450, Avg Q-Learn: 31.1602, Avg Random: 0.1348
# Game 5980000: Epsilon: 0.5444, Avg Q-Learn: 31.1087, Avg Random: 0.155
# Game 5990000: Epsilon: 0.5439, Avg Q-Learn: 31.2101, Avg Random: 0.1156
# Game 6000000: Epsilon: 0.5433, Avg Q-Learn: 31.1066, Avg Random: 0.1583
# Game 6010000: Epsilon: 0.5428, Avg Q-Learn: 31.1689, Avg Random: 0.1252
# Game 6020000: Epsilon: 0.5422, Avg Q-Learn: 31.1238, Avg Random: 0.167
# Game 6030000: Epsilon: 0.5417, Avg Q-Learn: 31.1567, Avg Random: 0.1119
# Game 6040000: Epsilon: 0.5412, Avg Q-Learn: 31.1159, Avg Random: 0.1443
# Game 6050000: Epsilon: 0.5406, Avg Q-Learn: 31.196, Avg Random: 0.1194
# Game 6060000: Epsilon: 0.5401, Avg Q-Learn: 31.1367, Avg Random: 0.1693
# Game 6070000: Epsilon: 0.5395, Avg Q-Learn: 31.2258, Avg Random: 0.1095
# Game 6080000: Epsilon: 0.5390, Avg Q-Learn: 31.1627, Avg Random: 0.1257
# Game 6090000: Epsilon: 0.5385, Avg Q-Learn: 31.144, Avg Random: 0.1109
# Game 6100000: Epsilon: 0.5379, Avg Q-Learn: 31.2002, Avg Random: 0.1331
# Game 6110000: Epsilon: 0.5374, Avg Q-Learn: 31.2374, Avg Random: 0.1412
# Game 6120000: Epsilon: 0.5368, Avg Q-Learn: 31.237, Avg Random: 0.1036
# Game 6130000: Epsilon: 0.5363, Avg Q-Learn: 31.1643, Avg Random: 0.1391
# Game 6140000: Epsilon: 0.5358, Avg Q-Learn: 31.246, Avg Random: 0.1276
# Game 6150000: Epsilon: 0.5352, Avg Q-Learn: 31.2331, Avg Random: 0.1219
# Game 6160000: Epsilon: 0.5347, Avg Q-Learn: 31.1546, Avg Random: 0.1458
# Game 6170000: Epsilon: 0.5342, Avg Q-Learn: 31.1205, Avg Random: 0.1689
# Game 6180000: Epsilon: 0.5336, Avg Q-Learn: 31.1725, Avg Random: 0.1506
# Game 6190000: Epsilon: 0.5331, Avg Q-Learn: 31.1497, Avg Random: 0.163
# Game 6200000: Epsilon: 0.5326, Avg Q-Learn: 31.2625, Avg Random: 0.127
# Game 6210000: Epsilon: 0.5320, Avg Q-Learn: 31.2172, Avg Random: 0.1005
# Game 6220000: Epsilon: 0.5315, Avg Q-Learn: 31.1461, Avg Random: 0.1161
# Game 6230000: Epsilon: 0.5310, Avg Q-Learn: 31.0804, Avg Random: 0.1395
# Game 6240000: Epsilon: 0.5304, Avg Q-Learn: 31.1578, Avg Random: 0.1411
# Game 6250000: Epsilon: 0.5299, Avg Q-Learn: 31.2487, Avg Random: 0.1124
# Game 6260000: Epsilon: 0.5294, Avg Q-Learn: 31.2609, Avg Random: 0.1273
# Game 6270000: Epsilon: 0.5289, Avg Q-Learn: 31.1853, Avg Random: 0.1019
# Game 6280000: Epsilon: 0.5283, Avg Q-Learn: 31.1648, Avg Random: 0.1389
# Game 6290000: Epsilon: 0.5278, Avg Q-Learn: 31.2303, Avg Random: 0.1422
# Game 6300000: Epsilon: 0.5273, Avg Q-Learn: 31.171, Avg Random: 0.1441
# Game 6310000: Epsilon: 0.5267, Avg Q-Learn: 31.3261, Avg Random: 0.1016
# Game 6320000: Epsilon: 0.5262, Avg Q-Learn: 31.1575, Avg Random: 0.1396
# Game 6330000: Epsilon: 0.5257, Avg Q-Learn: 31.1213, Avg Random: 0.1712
# Game 6340000: Epsilon: 0.5252, Avg Q-Learn: 31.2245, Avg Random: 0.1319
# Game 6350000: Epsilon: 0.5246, Avg Q-Learn: 31.2117, Avg Random: 0.1172
# Game 6360000: Epsilon: 0.5241, Avg Q-Learn: 31.1507, Avg Random: 0.1234
# Game 6370000: Epsilon: 0.5236, Avg Q-Learn: 31.249, Avg Random: 0.1349
# Game 6380000: Epsilon: 0.5231, Avg Q-Learn: 31.2193, Avg Random: 0.1218
# Game 6390000: Epsilon: 0.5225, Avg Q-Learn: 31.1778, Avg Random: 0.1339
# Game 6400000: Epsilon: 0.5220, Avg Q-Learn: 31.2321, Avg Random: 0.1304
# Game 6410000: Epsilon: 0.5215, Avg Q-Learn: 31.2467, Avg Random: 0.0978
# Game 6420000: Epsilon: 0.5210, Avg Q-Learn: 31.2935, Avg Random: 0.0958
# Game 6430000: Epsilon: 0.5205, Avg Q-Learn: 31.2882, Avg Random: 0.1407
# Game 6440000: Epsilon: 0.5199, Avg Q-Learn: 31.2813, Avg Random: 0.1513
# Game 6450000: Epsilon: 0.5194, Avg Q-Learn: 31.2041, Avg Random: 0.1308
# Game 6460000: Epsilon: 0.5189, Avg Q-Learn: 31.1731, Avg Random: 0.1197
# Game 6470000: Epsilon: 0.5184, Avg Q-Learn: 31.2204, Avg Random: 0.1401
# Game 6480000: Epsilon: 0.5179, Avg Q-Learn: 31.2455, Avg Random: 0.1264
# Game 6490000: Epsilon: 0.5173, Avg Q-Learn: 31.1925, Avg Random: 0.0997
# Game 6500000: Epsilon: 0.5168, Avg Q-Learn: 31.1652, Avg Random: 0.1331
# Game 6510000: Epsilon: 0.5163, Avg Q-Learn: 31.2848, Avg Random: 0.0799
# Game 6520000: Epsilon: 0.5158, Avg Q-Learn: 31.2421, Avg Random: 0.1405
# Game 6530000: Epsilon: 0.5153, Avg Q-Learn: 31.2251, Avg Random: 0.1189
# Game 6540000: Epsilon: 0.5148, Avg Q-Learn: 31.2558, Avg Random: 0.1284
# Game 6550000: Epsilon: 0.5142, Avg Q-Learn: 31.2312, Avg Random: 0.0852
# Game 6560000: Epsilon: 0.5137, Avg Q-Learn: 31.1809, Avg Random: 0.111
# Game 6570000: Epsilon: 0.5132, Avg Q-Learn: 31.2232, Avg Random: 0.1201
# Game 6580000: Epsilon: 0.5127, Avg Q-Learn: 31.2665, Avg Random: 0.1412
# Game 6590000: Epsilon: 0.5122, Avg Q-Learn: 31.2199, Avg Random: 0.11
# Game 6600000: Epsilon: 0.5117, Avg Q-Learn: 31.2485, Avg Random: 0.1505
# Game 6610000: Epsilon: 0.5112, Avg Q-Learn: 31.2876, Avg Random: 0.1015
# Game 6620000: Epsilon: 0.5107, Avg Q-Learn: 31.2831, Avg Random: 0.124
# Game 6630000: Epsilon: 0.5102, Avg Q-Learn: 31.2238, Avg Random: 0.1025
# Game 6640000: Epsilon: 0.5096, Avg Q-Learn: 31.2415, Avg Random: 0.1231
# Game 6650000: Epsilon: 0.5091, Avg Q-Learn: 31.2609, Avg Random: 0.1313
# Game 6660000: Epsilon: 0.5086, Avg Q-Learn: 31.25, Avg Random: 0.1167
# Game 6670000: Epsilon: 0.5081, Avg Q-Learn: 31.3459, Avg Random: 0.0884
# Game 6680000: Epsilon: 0.5076, Avg Q-Learn: 31.2064, Avg Random: 0.1594
# Game 6690000: Epsilon: 0.5071, Avg Q-Learn: 31.3006, Avg Random: 0.1298
# ...
# Game 7780000: Epsilon: 0.4547, Avg Q-Learn: 31.4392, Avg Random: 0.1237
# Game 7790000: Epsilon: 0.4543, Avg Q-Learn: 31.3709, Avg Random: 0.1233
# Game 7800000: Epsilon: 0.4538, Avg Q-Learn: 31.4433, Avg Random: 0.1284
# Game 7810000: Epsilon: 0.4534, Avg Q-Learn: 31.4625, Avg Random: 0.0923
# Game 7820000: Epsilon: 0.4529, Avg Q-Learn: 31.4635, Avg Random: 0.0991
# Game 7830000: Epsilon: 0.4525, Avg Q-Learn: 31.4739, Avg Random: 0.1183
# Game 7840000: Epsilon: 0.4520, Avg Q-Learn: 31.4663, Avg Random: 0.1208
# Game 7850000: Epsilon: 0.4516, Avg Q-Learn: 31.4183, Avg Random: 0.1137
# Game 7860000: Epsilon: 0.4511, Avg Q-Learn: 31.4235, Avg Random: 0.1361
# Game 7870000: Epsilon: 0.4507, Avg Q-Learn: 31.4549, Avg Random: 0.1416
# Game 7880000: Epsilon: 0.4502, Avg Q-Learn: 31.4755, Avg Random: 0.1263
# Game 7890000: Epsilon: 0.4498, Avg Q-Learn: 31.4961, Avg Random: 0.1118
# Game 7900000: Epsilon: 0.4493, Avg Q-Learn: 31.3984, Avg Random: 0.1546
# Game 7910000: Epsilon: 0.4489, Avg Q-Learn: 31.4692, Avg Random: 0.1465
# Game 7920000: Epsilon: 0.4484, Avg Q-Learn: 31.4328, Avg Random: 0.1374
# Game 7930000: Epsilon: 0.4480, Avg Q-Learn: 31.4373, Avg Random: 0.1324
# Game 7940000: Epsilon: 0.4475, Avg Q-Learn: 31.482, Avg Random: 0.0977
# Game 7950000: Epsilon: 0.4471, Avg Q-Learn: 31.5087, Avg Random: 0.0951
# Game 7960000: Epsilon: 0.4466, Avg Q-Learn: 31.4893, Avg Random: 0.1133
# Game 7970000: Epsilon: 0.4462, Avg Q-Learn: 31.424, Avg Random: 0.1345
# Game 7980000: Epsilon: 0.4457, Avg Q-Learn: 31.4781, Avg Random: 0.0833
# Game 7990000: Epsilon: 0.4453, Avg Q-Learn: 31.5353, Avg Random: 0.0967
# Game 8000000: Epsilon: 0.4448, Avg Q-Learn: 31.423, Avg Random: 0.1239
# Game 8010000: Epsilon: 0.4444, Avg Q-Learn: 31.4924, Avg Random: 0.1072
# Game 8020000: Epsilon: 0.4439, Avg Q-Learn: 31.4717, Avg Random: 0.1283
# Game 8030000: Epsilon: 0.4435, Avg Q-Learn: 31.5297, Avg Random: 0.0831
# Game 8040000: Epsilon: 0.4431, Avg Q-Learn: 31.4706, Avg Random: 0.1154
# Game 8050000: Epsilon: 0.4426, Avg Q-Learn: 31.481, Avg Random: 0.0873
# Game 8060000: Epsilon: 0.4422, Avg Q-Learn: 31.4139, Avg Random: 0.125
# Game 8070000: Epsilon: 0.4417, Avg Q-Learn: 31.4867, Avg Random: 0.1267
# Game 8080000: Epsilon: 0.4413, Avg Q-Learn: 31.5074, Avg Random: 0.1063
# Game 8090000: Epsilon: 0.4409, Avg Q-Learn: 31.4344, Avg Random: 0.1306
# Game 8100000: Epsilon: 0.4404, Avg Q-Learn: 31.5316, Avg Random: 0.1153
# Game 8110000: Epsilon: 0.4400, Avg Q-Learn: 31.5259, Avg Random: 0.0861
# Game 8120000: Epsilon: 0.4395, Avg Q-Learn: 31.5211, Avg Random: 0.1096
# Game 8130000: Epsilon: 0.4391, Avg Q-Learn: 31.5461, Avg Random: 0.1128
# Game 8140000: Epsilon: 0.4387, Avg Q-Learn: 31.581, Avg Random: 0.1063
# Game 8150000: Epsilon: 0.4382, Avg Q-Learn: 31.4763, Avg Random: 0.1134
# Game 8160000: Epsilon: 0.4378, Avg Q-Learn: 31.5093, Avg Random: 0.12
# Game 8170000: Epsilon: 0.4373, Avg Q-Learn: 31.4419, Avg Random: 0.108
# Game 8180000: Epsilon: 0.4369, Avg Q-Learn: 31.5356, Avg Random: 0.1332
# Game 8190000: Epsilon: 0.4365, Avg Q-Learn: 31.4927, Avg Random: 0.162
# Game 8200000: Epsilon: 0.4360, Avg Q-Learn: 31.4764, Avg Random: 0.1187
# Game 8210000: Epsilon: 0.4356, Avg Q-Learn: 31.5548, Avg Random: 0.1518
# Game 8220000: Epsilon: 0.4352, Avg Q-Learn: 31.5551, Avg Random: 0.0913
# Game 8230000: Epsilon: 0.4347, Avg Q-Learn: 31.4498, Avg Random: 0.115
# Game 8240000: Epsilon: 0.4343, Avg Q-Learn: 31.5173, Avg Random: 0.0932
# Game 8250000: Epsilon: 0.4339, Avg Q-Learn: 31.4495, Avg Random: 0.1114
# Game 8260000: Epsilon: 0.4334, Avg Q-Learn: 31.5239, Avg Random: 0.1162
# Game 8270000: Epsilon: 0.4330, Avg Q-Learn: 31.4506, Avg Random: 0.136
# Game 8280000: Epsilon: 0.4326, Avg Q-Learn: 31.5435, Avg Random: 0.1092
# Game 8290000: Epsilon: 0.4321, Avg Q-Learn: 31.4841, Avg Random: 0.1269
# Game 8300000: Epsilon: 0.4317, Avg Q-Learn: 31.4502, Avg Random: 0.1107
# Game 8310000: Epsilon: 0.4313, Avg Q-Learn: 31.5823, Avg Random: 0.0943
# Game 8320000: Epsilon: 0.4308, Avg Q-Learn: 31.564, Avg Random: 0.1013
# Game 8330000: Epsilon: 0.4304, Avg Q-Learn: 31.4835, Avg Random: 0.1227
# Game 8340000: Epsilon: 0.4300, Avg Q-Learn: 31.5346, Avg Random: 0.1079
# Game 8350000: Epsilon: 0.4295, Avg Q-Learn: 31.531, Avg Random: 0.113
# Game 8360000: Epsilon: 0.4291, Avg Q-Learn: 31.4816, Avg Random: 0.0973
# Game 8370000: Epsilon: 0.4287, Avg Q-Learn: 31.5018, Avg Random: 0.1001
# Game 8380000: Epsilon: 0.4282, Avg Q-Learn: 31.4881, Avg Random: 0.0938
# Game 8390000: Epsilon: 0.4278, Avg Q-Learn: 31.537, Avg Random: 0.1015
# Game 8400000: Epsilon: 0.4274, Avg Q-Learn: 31.6032, Avg Random: 0.0734
# Game 8410000: Epsilon: 0.4270, Avg Q-Learn: 31.4654, Avg Random: 0.1043
# Game 8420000: Epsilon: 0.4265, Avg Q-Learn: 31.5075, Avg Random: 0.1338
# Game 8430000: Epsilon: 0.4261, Avg Q-Learn: 31.5453, Avg Random: 0.1182
# Game 8440000: Epsilon: 0.4257, Avg Q-Learn: 31.5844, Avg Random: 0.095
# Game 8450000: Epsilon: 0.4253, Avg Q-Learn: 31.5765, Avg Random: 0.0768
# Game 8460000: Epsilon: 0.4248, Avg Q-Learn: 31.5578, Avg Random: 0.0968
# Game 8470000: Epsilon: 0.4244, Avg Q-Learn: 31.5395, Avg Random: 0.126
# Game 8480000: Epsilon: 0.4240, Avg Q-Learn: 31.5233, Avg Random: 0.1027
# Game 8490000: Epsilon: 0.4236, Avg Q-Learn: 31.6003, Avg Random: 0.0978
# Game 8500000: Epsilon: 0.4231, Avg Q-Learn: 31.5515, Avg Random: 0.1032
# Game 8510000: Epsilon: 0.4227, Avg Q-Learn: 31.5391, Avg Random: 0.1011
# Game 8520000: Epsilon: 0.4223, Avg Q-Learn: 31.5071, Avg Random: 0.1113
# Game 8530000: Epsilon: 0.4219, Avg Q-Learn: 31.5312, Avg Random: 0.1208
# Game 8540000: Epsilon: 0.4215, Avg Q-Learn: 31.5175, Avg Random: 0.1254
# Game 8550000: Epsilon: 0.4210, Avg Q-Learn: 31.6185, Avg Random: 0.0853
# Game 8560000: Epsilon: 0.4206, Avg Q-Learn: 31.5761, Avg Random: 0.1002
# Game 8570000: Epsilon: 0.4202, Avg Q-Learn: 31.5054, Avg Random: 0.0939
# Game 8580000: Epsilon: 0.4198, Avg Q-Learn: 31.5809, Avg Random: 0.1309
# Game 8590000: Epsilon: 0.4193, Avg Q-Learn: 31.608, Avg Random: 0.1039
# Game 8600000: Epsilon: 0.4189, Avg Q-Learn: 31.578, Avg Random: 0.1045
# Game 8610000: Epsilon: 0.4185, Avg Q-Learn: 31.5942, Avg Random: 0.107
# Game 8620000: Epsilon: 0.4181, Avg Q-Learn: 31.5508, Avg Random: 0.1074
# Game 8630000: Epsilon: 0.4177, Avg Q-Learn: 31.6184, Avg Random: 0.1032
# Game 8640000: Epsilon: 0.4173, Avg Q-Learn: 31.5861, Avg Random: 0.1083
# Game 8650000: Epsilon: 0.4168, Avg Q-Learn: 31.5935, Avg Random: 0.0803
# Game 8660000: Epsilon: 0.4164, Avg Q-Learn: 31.5248, Avg Random: 0.1179
# Game 8670000: Epsilon: 0.4160, Avg Q-Learn: 31.561, Avg Random: 0.1092
# Game 8680000: Epsilon: 0.4156, Avg Q-Learn: 31.584, Avg Random: 0.0994
# Game 8690000: Epsilon: 0.4152, Avg Q-Learn: 31.6103, Avg Random: 0.1
# Game 8700000: Epsilon: 0.4148, Avg Q-Learn: 31.5879, Avg Random: 0.0972
# Game 8710000: Epsilon: 0.4143, Avg Q-Learn: 31.5594, Avg Random: 0.1354
# Game 8720000: Epsilon: 0.4139, Avg Q-Learn: 31.5453, Avg Random: 0.1097
# Game 8730000: Epsilon: 0.4135, Avg Q-Learn: 31.6074, Avg Random: 0.0853
# Game 8740000: Epsilon: 0.4131, Avg Q-Learn: 31.5681, Avg Random: 0.1251
# Game 8750000: Epsilon: 0.4127, Avg Q-Learn: 31.5816, Avg Random: 0.1064
# Game 8760000: Epsilon: 0.4123, Avg Q-Learn: 31.6467, Avg Random: 0.101
# Game 8770000: Epsilon: 0.4119, Avg Q-Learn: 31.5542, Avg Random: 0.0965
# Game 8780000: Epsilon: 0.4115, Avg Q-Learn: 31.6466, Avg Random: 0.0941
# Game 8790000: Epsilon: 0.4110, Avg Q-Learn: 31.5838, Avg Random: 0.1076
# Game 8800000: Epsilon: 0.4106, Avg Q-Learn: 31.6756, Avg Random: 0.1116
# Game 8810000: Epsilon: 0.4102, Avg Q-Learn: 31.5732, Avg Random: 0.123
# Game 8820000: Epsilon: 0.4098, Avg Q-Learn: 31.5961, Avg Random: 0.1055
# Game 8830000: Epsilon: 0.4094, Avg Q-Learn: 31.5603, Avg Random: 0.136
# Game 8840000: Epsilon: 0.4090, Avg Q-Learn: 31.5851, Avg Random: 0.1309
# Game 8850000: Epsilon: 0.4086, Avg Q-Learn: 31.5497, Avg Random: 0.1348
# Game 8860000: Epsilon: 0.4082, Avg Q-Learn: 31.5473, Avg Random: 0.0835
# Game 8870000: Epsilon: 0.4078, Avg Q-Learn: 31.5657, Avg Random: 0.1473
# Game 8880000: Epsilon: 0.4074, Avg Q-Learn: 31.511, Avg Random: 0.1289
# Game 8890000: Epsilon: 0.4070, Avg Q-Learn: 31.5932, Avg Random: 0.0965
# Game 8900000: Epsilon: 0.4065, Avg Q-Learn: 31.5551, Avg Random: 0.1089
# Game 8910000: Epsilon: 0.4061, Avg Q-Learn: 31.5528, Avg Random: 0.1237
# Game 8920000: Epsilon: 0.4057, Avg Q-Learn: 31.5429, Avg Random: 0.1144
# Game 8930000: Epsilon: 0.4053, Avg Q-Learn: 31.579, Avg Random: 0.1054
# Game 8940000: Epsilon: 0.4049, Avg Q-Learn: 31.5762, Avg Random: 0.1344
# Game 8950000: Epsilon: 0.4045, Avg Q-Learn: 31.5398, Avg Random: 0.1412
# Game 8960000: Epsilon: 0.4041, Avg Q-Learn: 31.6345, Avg Random: 0.1042
# Game 8970000: Epsilon: 0.4037, Avg Q-Learn: 31.6192, Avg Random: 0.1119
# Game 8980000: Epsilon: 0.4033, Avg Q-Learn: 31.6186, Avg Random: 0.0741
# Game 8990000: Epsilon: 0.4029, Avg Q-Learn: 31.6667, Avg Random: 0.0697
# Game 9000000: Epsilon: 0.4025, Avg Q-Learn: 31.6572, Avg Random: 0.0772
# Game 9010000: Epsilon: 0.4021, Avg Q-Learn: 31.5906, Avg Random: 0.1056
# Game 9020000: Epsilon: 0.4017, Avg Q-Learn: 31.6867, Avg Random: 0.1258
# Game 9030000: Epsilon: 0.4013, Avg Q-Learn: 31.6606, Avg Random: 0.103
# Game 9040000: Epsilon: 0.4009, Avg Q-Learn: 31.5925, Avg Random: 0.1322
# Game 9050000: Epsilon: 0.4005, Avg Q-Learn: 31.6492, Avg Random: 0.0886
# Game 9060000: Epsilon: 0.4001, Avg Q-Learn: 31.5844, Avg Random: 0.115
# Game 9070000: Epsilon: 0.3997, Avg Q-Learn: 31.6803, Avg Random: 0.0688
# Game 9080000: Epsilon: 0.3993, Avg Q-Learn: 31.6444, Avg Random: 0.1171
# Game 9090000: Epsilon: 0.3989, Avg Q-Learn: 31.6131, Avg Random: 0.0905
# Game 9100000: Epsilon: 0.3985, Avg Q-Learn: 31.6372, Avg Random: 0.1115
# Game 9110000: Epsilon: 0.3981, Avg Q-Learn: 31.6858, Avg Random: 0.0802
# Game 9120000: Epsilon: 0.3977, Avg Q-Learn: 31.6061, Avg Random: 0.098
# Game 9130000: Epsilon: 0.3973, Avg Q-Learn: 31.6344, Avg Random: 0.0894
# Game 9140000: Epsilon: 0.3969, Avg Q-Learn: 31.6287, Avg Random: 0.069
# Game 9150000: Epsilon: 0.3965, Avg Q-Learn: 31.5903, Avg Random: 0.1408
# Game 9160000: Epsilon: 0.3961, Avg Q-Learn: 31.6734, Avg Random: 0.1594
# Game 9170000: Epsilon: 0.3957, Avg Q-Learn: 31.642, Avg Random: 0.1232
# Game 9180000: Epsilon: 0.3953, Avg Q-Learn: 31.6935, Avg Random: 0.1065
# Game 9190000: Epsilon: 0.3949, Avg Q-Learn: 31.6168, Avg Random: 0.1111
# Game 9200000: Epsilon: 0.3945, Avg Q-Learn: 31.721, Avg Random: 0.0778
# Game 9210000: Epsilon: 0.3941, Avg Q-Learn: 31.7291, Avg Random: 0.0785
# Game 9220000: Epsilon: 0.3937, Avg Q-Learn: 31.6632, Avg Random: 0.0943
# Game 9230000: Epsilon: 0.3934, Avg Q-Learn: 31.6341, Avg Random: 0.0912
# Game 9240000: Epsilon: 0.3930, Avg Q-Learn: 31.6255, Avg Random: 0.109
# Game 9250000: Epsilon: 0.3926, Avg Q-Learn: 31.6322, Avg Random: 0.1
# Game 9260000: Epsilon: 0.3922, Avg Q-Learn: 31.6225, Avg Random: 0.1002
# Game 9270000: Epsilon: 0.3918, Avg Q-Learn: 31.6832, Avg Random: 0.0955
# Game 9280000: Epsilon: 0.3914, Avg Q-Learn: 31.6322, Avg Random: 0.0824
# Game 9290000: Epsilon: 0.3910, Avg Q-Learn: 31.6299, Avg Random: 0.1029
# Game 9300000: Epsilon: 0.3906, Avg Q-Learn: 31.6468, Avg Random: 0.1416
# Game 9310000: Epsilon: 0.3902, Avg Q-Learn: 31.6877, Avg Random: 0.0677
# Game 9320000: Epsilon: 0.3898, Avg Q-Learn: 31.6472, Avg Random: 0.1178
# Game 9330000: Epsilon: 0.3894, Avg Q-Learn: 31.6319, Avg Random: 0.0799
# Game 9340000: Epsilon: 0.3890, Avg Q-Learn: 31.7117, Avg Random: 0.1207
# Game 9350000: Epsilon: 0.3887, Avg Q-Learn: 31.6656, Avg Random: 0.0931
# Game 9360000: Epsilon: 0.3883, Avg Q-Learn: 31.6656, Avg Random: 0.0947
# Game 9370000: Epsilon: 0.3879, Avg Q-Learn: 31.7371, Avg Random: 0.0828
# Game 9380000: Epsilon: 0.3875, Avg Q-Learn: 31.6622, Avg Random: 0.0938
# Game 9390000: Epsilon: 0.3871, Avg Q-Learn: 31.6778, Avg Random: 0.0857
# Game 9400000: Epsilon: 0.3867, Avg Q-Learn: 31.6573, Avg Random: 0.098
# Game 9410000: Epsilon: 0.3863, Avg Q-Learn: 31.6623, Avg Random: 0.0897
# Game 9420000: Epsilon: 0.3859, Avg Q-Learn: 31.6081, Avg Random: 0.1425
# Game 9430000: Epsilon: 0.3856, Avg Q-Learn: 31.6974, Avg Random: 0.1096
# Game 9440000: Epsilon: 0.3852, Avg Q-Learn: 31.751, Avg Random: 0.1032
# Game 9450000: Epsilon: 0.3848, Avg Q-Learn: 31.6326, Avg Random: 0.126
# Game 9460000: Epsilon: 0.3844, Avg Q-Learn: 31.6844, Avg Random: 0.1264
# Game 9470000: Epsilon: 0.3840, Avg Q-Learn: 31.6604, Avg Random: 0.0969
# Game 9480000: Epsilon: 0.3836, Avg Q-Learn: 31.6471, Avg Random: 0.1259
# Game 9490000: Epsilon: 0.3833, Avg Q-Learn: 31.7143, Avg Random: 0.1417
# Game 9500000: Epsilon: 0.3829, Avg Q-Learn: 31.6657, Avg Random: 0.1068
# Game 9510000: Epsilon: 0.3825, Avg Q-Learn: 31.7058, Avg Random: 0.1451
# Game 9520000: Epsilon: 0.3821, Avg Q-Learn: 31.6594, Avg Random: 0.0926
# Game 9530000: Epsilon: 0.3817, Avg Q-Learn: 31.613, Avg Random: 0.1029
# Game 9540000: Epsilon: 0.3813, Avg Q-Learn: 31.6727, Avg Random: 0.0799
# Game 9550000: Epsilon: 0.3810, Avg Q-Learn: 31.6764, Avg Random: 0.1046
# Game 9560000: Epsilon: 0.3806, Avg Q-Learn: 31.7253, Avg Random: 0.0767
# Game 9570000: Epsilon: 0.3802, Avg Q-Learn: 31.6655, Avg Random: 0.1449
# Game 9580000: Epsilon: 0.3798, Avg Q-Learn: 31.6382, Avg Random: 0.1249
# Game 9590000: Epsilon: 0.3794, Avg Q-Learn: 31.6925, Avg Random: 0.112
# Game 9600000: Epsilon: 0.3791, Avg Q-Learn: 31.7007, Avg Random: 0.0733
# Game 9610000: Epsilon: 0.3787, Avg Q-Learn: 31.6777, Avg Random: 0.1097
# Game 9620000: Epsilon: 0.3783, Avg Q-Learn: 31.7155, Avg Random: 0.094
# Game 9630000: Epsilon: 0.3779, Avg Q-Learn: 31.7657, Avg Random: 0.096
# Game 9640000: Epsilon: 0.3776, Avg Q-Learn: 31.6558, Avg Random: 0.085
# Game 9650000: Epsilon: 0.3772, Avg Q-Learn: 31.7168, Avg Random: 0.0859
# Game 9660000: Epsilon: 0.3768, Avg Q-Learn: 31.7302, Avg Random: 0.1023
# Game 9670000: Epsilon: 0.3764, Avg Q-Learn: 31.6284, Avg Random: 0.1035
# Game 9680000: Epsilon: 0.3760, Avg Q-Learn: 31.7381, Avg Random: 0.1003
# Game 9690000: Epsilon: 0.3757, Avg Q-Learn: 31.6862, Avg Random: 0.0881
# Game 9700000: Epsilon: 0.3753, Avg Q-Learn: 31.7525, Avg Random: 0.1221
# Game 9710000: Epsilon: 0.3749, Avg Q-Learn: 31.6659, Avg Random: 0.1035
# Game 9720000: Epsilon: 0.3745, Avg Q-Learn: 31.7174, Avg Random: 0.1088
# Game 9730000: Epsilon: 0.3742, Avg Q-Learn: 31.6527, Avg Random: 0.0831
# Game 9740000: Epsilon: 0.3738, Avg Q-Learn: 31.6809, Avg Random: 0.1054
# Game 9750000: Epsilon: 0.3734, Avg Q-Learn: 31.68, Avg Random: 0.102
# Game 9760000: Epsilon: 0.3730, Avg Q-Learn: 31.7202, Avg Random: 0.107
# Game 9770000: Epsilon: 0.3727, Avg Q-Learn: 31.7029, Avg Random: 0.0886
# Game 9780000: Epsilon: 0.3723, Avg Q-Learn: 31.6718, Avg Random: 0.1219
# Game 9790000: Epsilon: 0.3719, Avg Q-Learn: 31.7986, Avg Random: 0.0828
# Game 9800000: Epsilon: 0.3716, Avg Q-Learn: 31.6977, Avg Random: 0.0966
# Game 9810000: Epsilon: 0.3712, Avg Q-Learn: 31.6868, Avg Random: 0.0761
# Game 9820000: Epsilon: 0.3708, Avg Q-Learn: 31.7129, Avg Random: 0.0925
# Game 9830000: Epsilon: 0.3704, Avg Q-Learn: 31.7119, Avg Random: 0.0804
# Game 9840000: Epsilon: 0.3701, Avg Q-Learn: 31.721, Avg Random: 0.0774
# Game 9850000: Epsilon: 0.3697, Avg Q-Learn: 31.7265, Avg Random: 0.097
# Game 9860000: Epsilon: 0.3693, Avg Q-Learn: 31.6754, Avg Random: 0.119
# Game 9870000: Epsilon: 0.3690, Avg Q-Learn: 31.7757, Avg Random: 0.0625
# Game 9880000: Epsilon: 0.3686, Avg Q-Learn: 31.737, Avg Random: 0.0758
# Game 9890000: Epsilon: 0.3682, Avg Q-Learn: 31.7434, Avg Random: 0.1
# Game 9900000: Epsilon: 0.3679, Avg Q-Learn: 31.714, Avg Random: 0.1169
# Game 9910000: Epsilon: 0.3675, Avg Q-Learn: 31.7363, Avg Random: 0.0879
# Game 9920000: Epsilon: 0.3671, Avg Q-Learn: 31.7764, Avg Random: 0.0643
# Game 9930000: Epsilon: 0.3668, Avg Q-Learn: 31.7335, Avg Random: 0.0964
# Game 9940000: Epsilon: 0.3664, Avg Q-Learn: 31.7551, Avg Random: 0.0863
# Game 9950000: Epsilon: 0.3660, Avg Q-Learn: 31.7671, Avg Random: 0.0934
# Game 9960000: Epsilon: 0.3657, Avg Q-Learn: 31.7307, Avg Random: 0.0939
# Game 9970000: Epsilon: 0.3653, Avg Q-Learn: 31.7147, Avg Random: 0.1154
# Game 9980000: Epsilon: 0.3649, Avg Q-Learn: 31.7632, Avg Random: 0.1139
# Game 9990000: Epsilon: 0.3646, Avg Q-Learn: 31.776, Avg Random: 0.0623
# Game 10000000: Epsilon: 0.3642, Avg Q-Learn: 31.7174, Avg Random: 0.1076

# %%
import matplotlib.pyplot as plt
import numpy as np
window_size = 100000
rolling_avg_q = np.convolve(reward_history_q, np.ones(window_size)/window_size, mode='valid')
rolling_avg_random = np.convolve(reward_history_random, np.ones(window_size)/window_size, mode='valid')
plt.figure(figsize=(10, 5))
plt.plot(rolling_avg_q, label='Q-Learning Agent')
plt.plot(rolling_avg_random, label='Random Bot')
plt.xlabel('Epochs (x100 games)')
plt.ylabel('Average Reward')
plt.title('Learning Curve: Average Reward Over Time with Rolling Averages')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simulate_game(q_table):
    t = num_rounds
    s = 0
    current_bid_q = 0
    current_bid_random = 0
    highest_bids_q = []
    highest_bids_random = []

    while t > 0:
        state_q = (t, s)
        action_q = actions[np.argmax(q_table[state_q])]  # Choose best action from Q-table
        current_bid_q += action_q
        highest_bids_q.append(current_bid_q)

        action_random = np.random.choice(actions, p=p)
        current_bid_random += action_random
        highest_bids_random.append(current_bid_random)

        s = 1 if current_bid_q >= current_bid_random else 0
        t -= 1

    reward_q = (valuation - current_bid_q) if (current_bid_q > current_bid_random) and (current_bid_q <= valuation) else 0
    reward_random = (valuation - current_bid_random) if (current_bid_random > current_bid_q) and (current_bid_random <= valuation) else 0

    # Plotting the highest bids in correct round order with markers
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, num_rounds+1), highest_bids_q, 'x-', label='Q-Learning Agent Highest Bids', markersize=8)
    plt.plot(range(1, num_rounds+1), highest_bids_random, 'o-', label='Random Bot Highest Bids', markersize=5)
    plt.xlabel('Round')
    plt.ylabel('Highest Bid Amount')
    plt.title('Highest Bid Progression Over Rounds')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Reward for Q-Learning Agent: {reward_q}")
    print(f"Reward for Random Bot: {reward_random}")

# Example of calling the function with a pre-trained q_table
simulate_game(q_table)
# Out:
# Reward for Q-Learning Agent: 33
# Reward for Random Bot: 0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming q_table is the Q-table from the trained Q-learning model
num_rounds = 10  # Total number of rounds, from 10 to 1

# Extract optimal actions for each state of 's' across all rounds
optimal_actions_s0 = [np.argmax(q_table[t, 0]) for t in range(1, num_rounds+1)]
optimal_actions_s1 = [np.argmax(q_table[t, 1]) for t in range(1, num_rounds+1)]

# Plot the optimal actions
plt.figure(figsize=(10, 6))
plt.plot(range(1, num_rounds+1), optimal_actions_s0, 'o-', label='Optimal Actions when s=0')
plt.plot(range(1, num_rounds+1), optimal_actions_s1, 'x-', label='Optimal Actions when s=1')
plt.gca().invert_xaxis()  # Invert x-axis to show decreasing rounds from left to right
plt.xlabel('Remaining Rounds (t)')
plt.ylabel('Optimal Action')
plt.title('Optimal Actions from Q-Table for Different States of s')
plt.legend()
plt.grid(True)
plt.show()

# %%
def interactive_game(q_table):
    t = num_rounds
    s = 0  # Initial state: no one has the highest bid
    current_bid_q = 0
    current_bid_your = 0
    past_bids_q = []

    print("Starting the game. You will bid against the Q-learning bot.")

    while t > 0:
        state_q = (t, s)
        action_q = actions[np.argmax(q_table[state_q])]  # Bot selects the best action based on the Q-table
        current_bid_q += action_q
        past_bids_q.append(action_q)  # Store this round's bid for future reference

        # You enter your bid
        print(f"Round {num_rounds - t + 1}")
        print(f"Past bids by bot: {past_bids_q[:-1]}")  # Show all past bids except the current one
        print(f"Currently holding the highest bid: {'You' if s == 0 else 'Bot'}")

        try:
            bid = int(input("Enter your bid (0-4): "))
            if bid < 0 or bid > 10:
                print("Invalid bid. Please enter a value between 0 and 10.")
                continue
        except ValueError:
            print("Invalid input. Please enter an integer value.")
            continue

        current_bid_your += bid
        s = 1 if current_bid_q >= current_bid_your else 0  # Update the state based on who has the highest bid
        t -= 1  # Decrease the round

        print(f"Your total bid so far: {current_bid_your}\n")

    reward_q = (valuation - current_bid_q) if (current_bid_q > current_bid_your) and (current_bid_q <= valuation) else 0

    # Output results
    print("Game over.")
    print("Q-learning bot's total bid:", current_bid_q)
    print("Your total bid:", current_bid_your)
    print("Reward for Q-Learning Agent:", reward_q)

# Call this function to start an interactive game
interactive_game(q_table)

# %% [markdown]
# ### Eligibility Traces

# %%
import numpy as np

# Parameters
valuation = 50
discount_rate = 0.999
learning_rate = 0.01
lambda_ = 0.9  # Eligibility trace decay parameter
epsilon_start = 0.99
epsilon_min = 0.01
epsilon_decay = 0.99995
num_rounds = 10
num_actions = 5
num_games = 100000
verbose_interval = 10000

actions = np.arange(num_actions)  # Action space
q_table = np.random.uniform(valuation, valuation + 1, (num_rounds + 1, 2, len(actions)))  # Q-table
p = np.arange(num_actions, 0, -1)**3.0
p /= p.sum()

def train_agent():
    global epsilon_start, q_table  # Add q_table to global declarations

    reward_history_q = []
    reward_history_random = []
    epsilon = epsilon_start

    for game in range(num_games):
        # Initialize eligibility traces
        e_trace = np.zeros_like(q_table)

        t = num_rounds
        s = 0
        current_bid_q = 0
        current_bid_random = 0

        while t > 0:
            state_q = (t, s)
            if np.random.rand() < epsilon:
                action_q = np.random.choice(actions)
            else:
                action_q = actions[np.argmax(q_table[state_q])]

            current_bid_q += action_q
            action_random = np.random.choice(actions, p=p)
            current_bid_random += action_random
            s = 1 if current_bid_q >= current_bid_random else 0

            # Update eligibility trace
            e_trace *= discount_rate * lambda_
            e_trace[state_q][action_q] += 1

            if t == 1:  # Reward only on the final round
                reward_q = (valuation - current_bid_q) if (current_bid_q > current_bid_random) and (current_bid_q <= valuation) else 0
                reward_random = (valuation - current_bid_random) if (current_bid_random > current_bid_q) and (current_bid_random <= valuation) else 0

                # Q-value and eligibility trace update
                delta = reward_q - q_table[state_q][action_q]
                q_table += learning_rate * delta * e_trace

            t -= 1

        reward_history_q.append(reward_q)
        reward_history_random.append(reward_random)

        if (game + 1) % verbose_interval == 0:
            print(f"Game {game + 1}: Epsilon: {epsilon:.4f}, Avg Q-Learn: {np.mean(reward_history_q[-verbose_interval:])}, Avg Random: {np.mean(reward_history_random[-verbose_interval:])}")

        epsilon = max(epsilon_min, epsilon * epsilon_decay)

    return q_table, reward_history_q, reward_history_random

# Then train the agent
q_table, reward_history_q, reward_history_random = train_agent()
# Out:
# Game 10000: Epsilon: 0.6005, Avg Q-Learn: 32.6747, Avg Random: 0.3712
# Game 20000: Epsilon: 0.3642, Avg Q-Learn: 35.6787, Avg Random: 0.5622
# Game 30000: Epsilon: 0.2209, Avg Q-Learn: 36.9188, Avg Random: 0.6844
# Game 40000: Epsilon: 0.1340, Avg Q-Learn: 37.5807, Avg Random: 0.692
# Game 50000: Epsilon: 0.0813, Avg Q-Learn: 38.1507, Avg Random: 0.4835
# Game 60000: Epsilon: 0.0493, Avg Q-Learn: 38.1601, Avg Random: 0.4797
# Game 70000: Epsilon: 0.0299, Avg Q-Learn: 38.0396, Avg Random: 0.4523
# Game 80000: Epsilon: 0.0181, Avg Q-Learn: 38.6419, Avg Random: 0.384
# Game 90000: Epsilon: 0.0110, Avg Q-Learn: 38.5851, Avg Random: 0.468
# Game 100000: Epsilon: 0.0100, Avg Q-Learn: 38.6885, Avg Random: 0.4118

# %%
import matplotlib.pyplot as plt
import numpy as np
window_size = 10000
rolling_avg_q = np.convolve(reward_history_q, np.ones(window_size)/window_size, mode='valid')
rolling_avg_random = np.convolve(reward_history_random, np.ones(window_size)/window_size, mode='valid')
plt.figure(figsize=(10, 5))
plt.plot(rolling_avg_q, label='Q-Learning Agent')
plt.plot(rolling_avg_random, label='Random Bot')
plt.xlabel('Epochs (x100 games)')
plt.ylabel('Average Reward')
plt.title('Learning Curve: Average Reward Over Time with Rolling Averages')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simulate_game(q_table):
    t = num_rounds
    s = 0
    current_bid_q = 0
    current_bid_random = 0
    highest_bids_q = []
    highest_bids_random = []

    while t > 0:
        state_q = (t, s)
        action_q = actions[np.argmax(q_table[state_q])]  # Choose best action from Q-table
        current_bid_q += action_q
        highest_bids_q.append(current_bid_q)

        action_random = np.random.choice(actions, p=p)
        current_bid_random += action_random
        highest_bids_random.append(current_bid_random)

        s = 1 if current_bid_q >= current_bid_random else 0
        t -= 1

    reward_q = (valuation - current_bid_q) if (current_bid_q > current_bid_random) and (current_bid_q <= valuation) else 0
    reward_random = (valuation - current_bid_random) if (current_bid_random > current_bid_q) and (current_bid_random <= valuation) else 0

    # Plotting the highest bids in correct round order with markers
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, num_rounds+1), highest_bids_q, 'x-', label='Q-Learning Agent Highest Bids', markersize=8)
    plt.plot(range(1, num_rounds+1), highest_bids_random, 'o-', label='Random Bot Highest Bids', markersize=5)
    plt.xlabel('Round')
    plt.ylabel('Highest Bid Amount')
    plt.title('Highest Bid Progression Over Rounds')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Reward for Q-Learning Agent: {reward_q}")
    print(f"Reward for Random Bot: {reward_random}")

# Example of calling the function with a pre-trained q_table
simulate_game(q_table)
# Out:
# Reward for Q-Learning Agent: 41
# Reward for Random Bot: 0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming q_table is the Q-table from the trained Q-learning model
num_rounds = 10  # Total number of rounds, from 10 to 1

# Extract optimal actions for each state of 's' across all rounds
optimal_actions_s0 = [np.argmax(q_table[t, 0]) for t in range(1, num_rounds+1)]
optimal_actions_s1 = [np.argmax(q_table[t, 1]) for t in range(1, num_rounds+1)]

# Plot the optimal actions
plt.figure(figsize=(10, 6))
plt.plot(range(1, num_rounds+1), optimal_actions_s0, 'o-', label='Optimal Actions when s=0')
plt.plot(range(1, num_rounds+1), optimal_actions_s1, 'x-', label='Optimal Actions when s=1')
plt.gca().invert_xaxis()  # Invert x-axis to show decreasing rounds from left to right
plt.xlabel('Remaining Rounds (t)')
plt.ylabel('Optimal Action')
plt.title('Optimal Actions from Q-Table for Different States of s')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### vs Random-Creeper-OneShotter

# %%
# Fixing the probabilities issue by ensuring they sum to 1 for the creeper bot's random action

import numpy as np

# Parameters
val = 100
disc = 0.999
lr = 0.01
lam = 0.9
eps_start = 0.99
eps_min = 0.01
eps_decay = 0.999999  # Reduced epsilon decay
rounds = 10
actions = 10
games = 3000000
verbose = 100000

acts = np.arange(actions)
q_tab = np.random.uniform(val, val + 1, (rounds + 1, 2, 2, actions))

def random_bot_type():
    return np.random.choice(["creeper", "sniper"])

def random_bot_action(bot_type, t, holds_bid):
    if bot_type == "creeper":
        if holds_bid:
            probs = [0.6] + [0.1] * (actions - 1)
            return np.random.choice(acts, p=probs/np.sum(probs))
        else:
            probs = [0.1] * (actions - 1) + [0.2]
            return np.random.choice(acts, p=probs/np.sum(probs))
    elif bot_type == "sniper" and t == 1:
        return actions - 1
    else:
        return 0

def train_agent():
    global eps_start, q_tab

    r_hist_q = []
    r_hist_rnd = []
    eps = eps_start

    for game in range(games):
        e_trace = np.zeros_like(q_tab)
        bot_type = random_bot_type()
        held_count = 0

        t = rounds
        s = 0
        current_bid_q = 0
        current_bid_rnd = 0

        while t > 0:
            state_q = (t, s, min(1, held_count))  # Ensure held_count is within bounds
            if np.random.rand() < eps:
                act_q = np.random.choice(acts)
            else:
                act_q = acts[np.argmax(q_tab[state_q])]

            current_bid_q += act_q
            act_rnd = random_bot_action(bot_type, t, current_bid_rnd >= current_bid_q)
            current_bid_rnd += act_rnd
            s = 1 if current_bid_q >= current_bid_rnd else 0
            if s == 1:
                held_count += 1

            e_trace *= disc * lam
            e_trace[state_q][act_q] += 1

            if t == 1:
                reward_q = (val - current_bid_q) if (current_bid_q > current_bid_rnd) and (current_bid_q <= val) else 0
                reward_rnd = (val - current_bid_rnd) if (current_bid_rnd > current_bid_q) and (current_bid_rnd <= val) else 0
                delta = reward_q - q_tab[state_q][act_q]
                q_tab += lr * delta * e_trace

            t -= 1

        r_hist_q.append(reward_q)
        r_hist_rnd.append(reward_rnd)

        if (game + 1) % verbose == 0:
            print(f"Game {game + 1}: Eps: {eps:.4f}, Avg Q: {np.mean(r_hist_q[-verbose:]):.4f}, Avg Rnd: {np.mean(r_hist_rnd[-verbose:]):.4f}")

        eps = max(eps_min, eps * eps_decay)

    return q_tab, r_hist_q, r_hist_rnd

q_tab, r_hist_q, r_hist_rnd = train_agent()
# Out:
# Game 100000: Eps: 0.8958, Avg Q: 40.2698, Avg Rnd: 13.2304
# Game 200000: Eps: 0.8105, Avg Q: 40.8237, Avg Rnd: 15.4437
# Game 300000: Eps: 0.7334, Avg Q: 41.7089, Avg Rnd: 16.6590
# Game 400000: Eps: 0.6636, Avg Q: 42.7359, Avg Rnd: 17.4506
# Game 500000: Eps: 0.6005, Avg Q: 43.7209, Avg Rnd: 17.7124
# Game 600000: Eps: 0.5433, Avg Q: 44.7708, Avg Rnd: 17.9024
# Game 700000: Eps: 0.4916, Avg Q: 45.3163, Avg Rnd: 18.0169
# Game 800000: Eps: 0.4448, Avg Q: 45.9251, Avg Rnd: 18.1286
# Game 900000: Eps: 0.4025, Avg Q: 46.3383, Avg Rnd: 18.3254
# Game 1000000: Eps: 0.3642, Avg Q: 46.8824, Avg Rnd: 18.2875
# Game 1100000: Eps: 0.3295, Avg Q: 46.6689, Avg Rnd: 18.6920
# Game 1200000: Eps: 0.2982, Avg Q: 46.7651, Avg Rnd: 18.6748
# Game 1300000: Eps: 0.2698, Avg Q: 46.7038, Avg Rnd: 18.5257
# Game 1400000: Eps: 0.2441, Avg Q: 46.4301, Avg Rnd: 18.2522
# Game 1500000: Eps: 0.2209, Avg Q: 45.7225, Avg Rnd: 18.5311
# Game 1600000: Eps: 0.1999, Avg Q: 45.6407, Avg Rnd: 17.6989
# Game 1700000: Eps: 0.1809, Avg Q: 49.0611, Avg Rnd: 17.5975
# Game 1800000: Eps: 0.1636, Avg Q: 50.4122, Avg Rnd: 17.6885
# Game 1900000: Eps: 0.1481, Avg Q: 50.8760, Avg Rnd: 17.6283
# Game 2000000: Eps: 0.1340, Avg Q: 51.1068, Avg Rnd: 17.7515
# Game 2100000: Eps: 0.1212, Avg Q: 51.5208, Avg Rnd: 17.5291
# Game 2200000: Eps: 0.1097, Avg Q: 51.8505, Avg Rnd: 17.4629
# Game 2300000: Eps: 0.0993, Avg Q: 52.1632, Avg Rnd: 17.2114
# Game 2400000: Eps: 0.0898, Avg Q: 52.4613, Avg Rnd: 17.1619
# Game 2500000: Eps: 0.0813, Avg Q: 52.9287, Avg Rnd: 16.9797
# Game 2600000: Eps: 0.0735, Avg Q: 53.3090, Avg Rnd: 16.7481
# Game 2700000: Eps: 0.0665, Avg Q: 53.4686, Avg Rnd: 16.7066
# Game 2800000: Eps: 0.0602, Avg Q: 54.0188, Avg Rnd: 16.3230
# Game 2900000: Eps: 0.0545, Avg Q: 54.0354, Avg Rnd: 16.4859
# Game 3000000: Eps: 0.0493, Avg Q: 54.4275, Avg Rnd: 16.1611

# %%
import numpy as np
import matplotlib.pyplot as plt

def simulate_game(q_table, bot_type="creeper"):
    t = rounds
    s = 0
    held_count = 0
    current_bid_q = 0
    current_bid_rnd = 0
    highest_bids_q = []
    highest_bids_rnd = []

    while t > 0:
        state_q = (t, s, min(1, held_count))  # Ensure held_count is within bounds
        action_q = acts[np.argmax(q_table[state_q])]  # Choose best action from Q-table
        current_bid_q += action_q
        highest_bids_q.append(current_bid_q)

        action_rnd = random_bot_action(bot_type, t, current_bid_rnd >= current_bid_q)
        current_bid_rnd += action_rnd
        highest_bids_rnd.append(current_bid_rnd)

        s = 1 if current_bid_q >= current_bid_rnd else 0
        if s == 1:
            held_count += 1
        t -= 1

    reward_q = (val - current_bid_q) if (current_bid_q > current_bid_rnd) and (current_bid_q <= val) else 0
    reward_rnd = (val - current_bid_rnd) if (current_bid_rnd > current_bid_q) and (current_bid_rnd <= val) else 0

    plt.figure(figsize=(10, 5))
    plt.plot(range(1, rounds+1), highest_bids_q, 'x-', label='Q-Learning Agent Highest Bids', markersize=8)
    plt.plot(range(1, rounds+1), highest_bids_rnd, 'o-', label=f'{bot_type.capitalize()} Bot Highest Bids', markersize=5)
    plt.xlabel('Round')
    plt.ylabel('Highest Bid Amount')
    plt.title(f'Highest Bid Progression Over Rounds against {bot_type.capitalize()} Bot')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Reward for Q-Learning Agent: {reward_q}")
    print(f"Reward for {bot_type.capitalize()} Bot: {reward_rnd}")

# Example of calling the function with a pre-trained q_table against a creeper bot
simulate_game(q_tab, bot_type="creeper")

# Example of calling the function with a pre-trained q_table against a sniper bot
simulate_game(q_tab, bot_type="sniper")
# Out:
# Reward for Q-Learning Agent: 59
# Reward for Creeper Bot: 0
# Reward for Q-Learning Agent: 90
# Reward for Sniper Bot: 0

# %% [markdown]
# ### Vs 3 Types

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
val = 100
disc = 0.999
lr = 0.01
lam = 0.9
eps_start = 0.99
eps_min = 0.01
eps_decay = 0.999999  # Reduced epsilon decay
rounds = 10
actions = 10
games = 3000000
verbose = 100000

acts = np.arange(actions)
q_tab = np.random.uniform(val, val + 1, (rounds + 1, 2, 2, actions))

def random_bot_type():
    return np.random.choice(["creeper", "sniper", "one_shotter"], p=[0.33, 0.33, 0.34])

def random_bot_action(bot_type, t, holds_bid):
    if bot_type == "creeper":
        if holds_bid:
            probs = [0.6] + [0.1] * (actions - 1)
            return np.random.choice(acts, p=probs/np.sum(probs))
        else:
            probs = [0.1] * (actions - 1) + [0.2]
            return np.random.choice(acts, p=probs/np.sum(probs))
    elif bot_type == "sniper" and t == 1:
        return actions - 1
    elif bot_type == "one_shotter" and t == rounds:
        return actions - 3  # One-shotter bids fairly high early on
    else:
        return 0

def train_agent():
    global eps_start, q_tab

    r_hist_q = []
    r_hist_rnd = []
    eps = eps_start

    for game in range(games):
        e_trace = np.zeros_like(q_tab)
        bot_type = random_bot_type()
        held_count = 0

        t = rounds
        s = 0
        current_bid_q = 0
        current_bid_rnd = 0

        while t > 0:
            state_q = (t, s, min(1, held_count))  # Ensure held_count is within bounds
            if np.random.rand() < eps:
                act_q = np.random.choice(acts)
            else:
                act_q = acts[np.argmax(q_tab[state_q])]

            current_bid_q += act_q
            act_rnd = random_bot_action(bot_type, t, current_bid_rnd >= current_bid_q)
            current_bid_rnd += act_rnd
            s = 1 if current_bid_q >= current_bid_rnd else 0
            if s == 1:
                held_count += 1

            e_trace *= disc * lam
            e_trace[state_q][act_q] += 1

            if t == 1:
                reward_q = (val - current_bid_q) if (current_bid_q > current_bid_rnd) and (current_bid_q <= val) else 0
                reward_rnd = (val - current_bid_rnd) if (current_bid_rnd > current_bid_q) and (current_bid_rnd <= val) else 0
                delta = reward_q - q_tab[state_q][act_q]
                q_tab += lr * delta * e_trace

            t -= 1

        r_hist_q.append(reward_q)
        r_hist_rnd.append(reward_rnd)

        if (game + 1) % verbose == 0:
            print(f"Game {game + 1}: Eps: {eps:.4f}, Avg Q: {np.mean(r_hist_q[-verbose:]):.4f}, Avg Rnd: {np.mean(r_hist_rnd[-verbose:]):.4f}")

        eps = max(eps_min, eps * eps_decay)

    return q_tab, r_hist_q, r_hist_rnd

q_tab, r_hist_q, r_hist_rnd = train_agent()

def simulate_game(q_table, bot_type="creeper"):
    t = rounds
    s = 0
    held_count = 0
    current_bid_q = 0
    current_bid_rnd = 0
    highest_bids_q = []
    highest_bids_rnd = []

    while t > 0:
        state_q = (t, s, min(1, held_count))  # Ensure held_count is within bounds
        action_q = acts[np.argmax(q_table[state_q])]  # Choose best action from Q-table
        current_bid_q += action_q
        highest_bids_q.append(current_bid_q)

        action_rnd = random_bot_action(bot_type, t, current_bid_rnd >= current_bid_q)
        current_bid_rnd += action_rnd
        highest_bids_rnd.append(current_bid_rnd)

        s = 1 if current_bid_q >= current_bid_rnd else 0
        if s == 1:
            held_count += 1
        t -= 1

    reward_q = (val - current_bid_q) if (current_bid_q > current_bid_rnd) and (current_bid_q <= val) else 0
    reward_rnd = (val - current_bid_rnd) if (current_bid_rnd > current_bid_q) and (current_bid_rnd <= val) else 0

    plt.figure(figsize=(10, 5))
    plt.plot(range(1, rounds+1), highest_bids_q, 'x-', label='Q-Learning Agent Highest Bids', markersize=8)
    plt.plot(range(1, rounds+1), highest_bids_rnd, 'o-', label=f'{bot_type.capitalize()} Bot Highest Bids', markersize=5)
    plt.xlabel('Round')
    plt.ylabel('Highest Bid Amount')
    plt.title(f'Highest Bid Progression Over Rounds against {bot_type.capitalize()} Bot')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Reward for Q-Learning Agent: {reward_q}")
    print(f"Reward for {bot_type.capitalize()} Bot: {reward_rnd}")

# Example of calling the function with a pre-trained q_table against a creeper bot
simulate_game(q_tab, bot_type="creeper")
simulate_game(q_tab, bot_type="sniper")
simulate_game(q_tab, bot_type="one_shotter")
# Out:
# Game 100000: Eps: 0.8958, Avg Q: 45.9906, Avg Rnd: 8.7293
# Game 200000: Eps: 0.8105, Avg Q: 47.5699, Avg Rnd: 10.2712
# Game 300000: Eps: 0.7334, Avg Q: 49.1630, Avg Rnd: 11.3438
# Game 400000: Eps: 0.6636, Avg Q: 50.6928, Avg Rnd: 12.2674
# Game 500000: Eps: 0.6005, Avg Q: 51.4662, Avg Rnd: 13.3948
# Game 600000: Eps: 0.5433, Avg Q: 52.1895, Avg Rnd: 14.3106
# Game 700000: Eps: 0.4916, Avg Q: 53.2428, Avg Rnd: 14.7820
# Game 800000: Eps: 0.4448, Avg Q: 53.4987, Avg Rnd: 15.6134
# Game 900000: Eps: 0.4025, Avg Q: 54.2678, Avg Rnd: 15.6548
# Game 1000000: Eps: 0.3642, Avg Q: 54.5733, Avg Rnd: 15.8590
# Game 1100000: Eps: 0.3295, Avg Q: 55.0697, Avg Rnd: 16.0960
# Game 1200000: Eps: 0.2982, Avg Q: 55.4800, Avg Rnd: 16.2407
# Game 1300000: Eps: 0.2698, Avg Q: 55.7751, Avg Rnd: 16.4967
# Game 1400000: Eps: 0.2441, Avg Q: 56.3219, Avg Rnd: 16.7418
# Game 1500000: Eps: 0.2209, Avg Q: 56.5679, Avg Rnd: 16.9955
# Game 1600000: Eps: 0.1999, Avg Q: 56.9655, Avg Rnd: 16.9956
# Game 1700000: Eps: 0.1809, Avg Q: 57.1330, Avg Rnd: 17.2853
# Game 1800000: Eps: 0.1636, Avg Q: 57.5110, Avg Rnd: 17.4521
# Game 1900000: Eps: 0.1481, Avg Q: 57.7318, Avg Rnd: 17.7690
# Game 2000000: Eps: 0.1340, Avg Q: 58.1195, Avg Rnd: 17.6782
# Game 2100000: Eps: 0.1212, Avg Q: 58.5677, Avg Rnd: 17.5169
# Game 2200000: Eps: 0.1097, Avg Q: 58.7472, Avg Rnd: 17.8230
# Game 2300000: Eps: 0.0993, Avg Q: 58.7973, Avg Rnd: 17.8995
# Game 2400000: Eps: 0.0898, Avg Q: 59.1906, Avg Rnd: 17.9193
# Game 2500000: Eps: 0.0813, Avg Q: 59.3401, Avg Rnd: 17.9437
# Game 2600000: Eps: 0.0735, Avg Q: 59.2733, Avg Rnd: 18.2460
# Game 2700000: Eps: 0.0665, Avg Q: 59.5405, Avg Rnd: 18.1725
# Game 2800000: Eps: 0.0602, Avg Q: 59.7898, Avg Rnd: 18.2868
# Game 2900000: Eps: 0.0545, Avg Q: 60.2296, Avg Rnd: 18.0727
# Game 3000000: Eps: 0.0493, Avg Q: 60.0571, Avg Rnd: 18.4448
# Reward for Q-Learning Agent: 66
# Reward for Creeper Bot: 0
# Reward for Q-Learning Agent: 88
# Reward for Sniper Bot: 0
# Reward for Q-Learning Agent: 88
# Reward for One_shotter Bot: 0

# %%
simulate_game(q_tab, bot_type="creeper")
simulate_game(q_tab, bot_type="sniper")
simulate_game(q_tab, bot_type="one_shotter")
# Out:
# Reward for Q-Learning Agent: 65
# Reward for Creeper Bot: 0
# Reward for Q-Learning Agent: 88
# Reward for Sniper Bot: 0
# Reward for Q-Learning Agent: 88
# Reward for One_shotter Bot: 0
